# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.api.training import get_training_results
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader
# Out:
# [2020-05-25 09:35:30,573] INFO in __init__: RobotEHR API

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=15)

# %%
feature_pipeline = FeaturePipeline.load(id=22)

# %%
import morpher.config
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__',
    #'any__Procedure__', 
    #'any__Drug__', 
    #'any__Material__', 
    #'any__Encounter__', 
    #'any__AlcoholUse__', 
    #'any__DrugUse__', 
    #'any__TobaccoUse__',
]

agg_func_regex = ""
for r in regexes:
    agg_func_regex += r + "|"
agg_func_regex = agg_func_regex[:-1]

def prepare_data_function(data, target):
    import morpher
    from morpher.jobs import Impute, Scale
    from sklearn.preprocessing import OneHotEncoder
    from enum import Enum
    
    # remove unused features
    del data['medical_record_number']
    del data['mother_account_number']
    del data['date_of_birth']
    del data['month_of_birth']
    del data['patient_ethnic_group']
    del data['religion']
    del data['address_zip']
    del data['deceased_indicator']
    del data['marital_status_code']
    
    class RaceType(str, Enum):
        AFRICAN = 'African'
        AMERICAN_BLACK = 'Black or African-American'
        AMERICAN_NATIVE = 'Native American'
        ASIAN = 'Asian'
        ASIAN_PACIFIC = 'Asian Pacific'
        ASIAN_INDIAN = 'Asian Indian'
        ASIAN_CHINESE = 'Asian Chinese'
        HISPANIC = 'Hispanic or Latino'
        OTHER = 'Other'
        WHITE = 'White'
    
    RACE_MAPPING = {
        RaceType.AFRICAN: [
            'Cape Verdian',
            'Congolese',
            'Eritrean',
            'Ethiopian',
            'Gabonian',
            'Ghanaian',
            'Guinean',
            'Ivory Coastian',
            'Kenyan',
            'Liberian',
            'Madagascar',
            'Malian',
            'Nigerian',
            'Other: East African',
            'Other: North African',
            'Other: South African',
            'Other: West African',
            'Senegalese',
            'Sierra Leonean',
            'Somalian',
            'Sudanese',
            'Tanzanian',
            'Togolese',
            'Ugandan',
            'Zimbabwean'
        ],
        RaceType.AMERICAN_BLACK: [
            'African American (Black)',
            'African-American',
            'Black Or African-American',
            'Black or African - American',
        ],
        RaceType.AMERICAN_NATIVE: [
            'American (Indian/Alaskan)',
            'Native American'
        ],
        RaceType.ASIAN: [
            'Asian',
            'Bangladeshi',
            'Bhutanese',
            'Burmese',
            'Cambodian',
            'Hmong',
            'Indonesian',
            'Japanese',
            'Korean',
            'Laotian',
            'Malaysian',
            'Maldivian',
            'Nepalese',
            'Okinawan',
            'Pakistani',
            'Singaporean',
            'Taiwanese',
            'Thai',
            'Vietnamese',
            'Yapese'
        ],
        RaceType.ASIAN_PACIFIC: [
            'Asian (Pacific Islander)',
            'Carolinian',
            'Chamorro',
            'Chuukese',
            'Fijian',
            'Filipino',
            'Guamanian',
            'Guamanian Or Chamorro',
            'Guamanian or Chamorro',
            'Iwo Jiman',
            'Kiribati',
            'Kosraean',
            'Mariana Islander',
            'Marshallese',
            'Melanesian',
            'Micronesian',
            'Native Hawaiian',
            'New Hebrides',
            'Other Pacific Islander',
            'Pacific Islander',
            'Palauan',
            'Pohnpeian',
            'Polynesian',
            'Saipanese',
            'Samoan',
            'Papua New Guinean',
            'Tahitian',
            'Tokelauan',
            'Tongan'
        ],
        RaceType.ASIAN_INDIAN: [
            'Asian Indian',
            'Sri Lankan',
            'Sri lankan',
            'West Indian'
        ],
        RaceType.ASIAN_CHINESE: [
            'Chinese',
        ],
        RaceType.HISPANIC: [
            'Barbadian',
            'Dominica Islander',
            'Grenadian',
            'Haitian',
            'Hispanic/Latino',
            'Jamaican',
            'St Vincentian',
            'Trinidadian'
        ],
        RaceType.OTHER: [
            '',
            'Aa',
            'Ab',
            'Af',
            'Ag',
            'Ak',
            'Al',
            'Ap',
            'Ar',
            'Av',
            'Ay',
            'B',
            'B1',
            'B2',
            'B3',
            'B4',
            'B5',
            'B6',
            'B7',
            'B8',
            'B9',
            'Ba',
            'Bb',
            'Bc',
            'Bd',
            'Be',
            'Bf',
            'Bg',
            'Bh',
            'Bj',
            'Bk',
            'Bm',
            'Bn',
            'Bo',
            'Bp',
            'Bq',
            'Br',
            'Bs',
            'Bt',
            'Bu',
            'Bv',
            'Bw',
            'Bx',
            'By',
            'Bz',
            'I',
            'MSDW_NOT APPLICABLE',
            'MSDW_OTHER',
            'MSDW_UNKNOWN',
            'NOT AVAILABLE',
            'Non Hispanic',
            'O',
            'Other',
            'Pk',
            'Pl',
            'Pm',
            'Po',
            'Ps',
            'Pv',
            'U',
            'Unk',
            'Unknown',
            'W'
        ],
        RaceType.WHITE: [
            'Caucasian (White)',
            'White'
        ]
    }
    
    # value mapping
    data['race'] = (
        data.race.map({
            label: cat for cat, labels in RACE_MAPPING.items()
            for label in labels
        }).astype(pd.api.types.CategoricalDtype(RaceType))
    )
    
    # pre-encoding nan handling
    for column in ['gender', 'race']:
        enc = OneHotEncoder(sparse=False)
        transformed_data = enc.fit_transform(data[[column]])
        transformed_columns = pd.DataFrame(
            data=transformed_data, 
            columns=[f'{column}_{c}' for c in enc.categories_[0]]
        )
        data = data.join(transformed_columns)
        del data[column]
        
    label_encoded_data = data.copy()
    
    label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]] = label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]].fillna(False)
    
    scaled_data, _ = Scale().execute(data=label_encoded_data, target=target)
    
    imputed_data, _ = Impute().execute(data=scaled_data, imputation_method=morpher.config.imputers.DEFAULT)
    
    return imputed_data

data_loader = DataLoader(agg_func_regex, prepare_data_function)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [0.05]
observation_windows_occurring = [[-361, -1]]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator]
targets = ['cytomegaloviral_disease_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.BORDERLINE, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-5 CMV + numeric focus',
    version='25.0.0',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric_time_series",
    rfe__run=True,
    rfe__step_size=50
)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7ff418e38390>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 372 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 598.936ms
#
# Fitting estimator with 322 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 355.223ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 225.168ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 131.59ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 353.388ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 242.601ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 455.935ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 522.908ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 991.741ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 883.645ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.299ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 934.988ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 900.632ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 859.572ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 120.503ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 718.616ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.982ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 241.356ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 231.38ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 197.777ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 83.514ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 114.411ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 999.627ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 994.573ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 356.685ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 404.028ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 350.492ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 477.824ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 386.499ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 570.287ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 452.789ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 318.331ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 558.814ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 314.283ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 322.298ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 333.339ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 439.157ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 446.519ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 460.05ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 470.178ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 452.281ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 239.704ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 494.581ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 354.543ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 485.687ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 222.861ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 840.309ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 890.408ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.974ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 723.645ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 863.146ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 200.321ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 193.29ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 202.411ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 228.735ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 192.838ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# Fitting estimator with 372 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 189.541ms
#
# Fitting estimator with 322 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 108.572ms
#
# Fitting estimator with 272 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 77.349ms
#
# Fitting estimator with 222 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 50.532ms
#
# Fitting estimator with 172 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 38.419ms
#
# Fitting estimator with 122 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.028ms
#
# Fitting estimator with 72 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.07ms
#
# Fitting estimator with 22 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.772ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.473ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.812ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.509ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.124ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.924ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.668ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.218ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.284ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.804ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.096ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.219ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.376ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.71ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.27ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.326ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.766ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.682ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.29ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.42ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.496ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.909ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.931ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.731ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.347ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.839ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.414ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.76ms
#
# Fitting estimator with 372 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 589.297ms
#
# Fitting estimator with 322 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 433.26ms
#
# Fitting estimator with 272 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 672.027ms
#
# Fitting estimator with 222 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 552.046ms
#
# Fitting estimator with 172 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 760.965ms
#
# Fitting estimator with 122 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 628.081ms
#
# Fitting estimator with 72 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 391.738ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 140.573ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 141.713ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 164.249ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 111.317ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 134.536ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 163.071ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 115.097ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 8.904ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.832ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.518ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 10.158ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 9.556ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 49.527ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 35.713ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 38.478ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 45.113ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 36.233ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 39.215ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 27.703ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 34.638ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 37.373ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 32.078ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 42.356ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 52.907ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 87.854ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 95.497ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 53.917ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7ff418e93828>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 372 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 185.242ms
#
# Fitting estimator with 322 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 544.151ms
#
# Fitting estimator with 272 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 950.917ms
#
# Fitting estimator with 222 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 546.348ms
#
# Fitting estimator with 172 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.492ms
#
# Fitting estimator with 122 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 500.923ms
#
# Fitting estimator with 72 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.249ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 440.307ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 454.6ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 661.888ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 663.173ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 681.693ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 660.505ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 663.916ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 129.66ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 131.899ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 137.007ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 136.67ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 138.461ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 831.785ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 824.258ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 848.508ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 841.59ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 842.229ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 836.109ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 957.257ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 726.657ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 40.492ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 39.047ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 79.147ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 467.83ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 750.684ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 733.24ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 708.5ms
#
# Fitting estimator with 372 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 640.352ms
#
# Fitting estimator with 322 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.637ms
#
# Fitting estimator with 272 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 789.843ms
#
# Fitting estimator with 222 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.229ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 881.556ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 621.328ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 199.309ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 650.491ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 814.858ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 601.968ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 311.062ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 871.962ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 378.499ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 438.872ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 965.492ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 535.408ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 770.633ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 755.942ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 675.326ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 733.918ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 784.403ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 429.871ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 609.756ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 417.589ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 304.585ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 323.117ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 707.177ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 740.484ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 705.529ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 725.718ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 726.118ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# Fitting estimator with 372 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.057ms
#
# Fitting estimator with 322 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.427ms
#
# Fitting estimator with 272 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 25.338ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 22.005ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 22.525ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 38.969ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.38ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.574ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.12ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.094ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.163ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.929ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.834ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.67ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.098ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.501ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.915ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 69.204ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.648ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 69.294ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.362ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 69.46ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 65.847ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 65.058ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.884ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.892ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.311ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.21ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.402ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.702ms
#
# Fitting estimator with 372 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 445.57ms
#
# Fitting estimator with 322 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 452.859ms
#
# Fitting estimator with 272 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 268.544ms
#
# Fitting estimator with 222 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 221.094ms
#
# Fitting estimator with 172 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 281.48ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 328.792ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 277.174ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 346.252ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 296.389ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 277.345ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 347.358ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 154.751ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 43.555ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.091ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.539ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.557ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 36.419ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 137.846ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 128.523ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 141.012ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 140.366ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 289.08ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 308.383ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 240.245ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 146.734ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 188.208ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 284.828ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 276.94ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 277.139ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 175.253ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 177.87ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 170.138ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7ff418e80400>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 834.959ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 822.534ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 154.012ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 829.988ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 656.539ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.349ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 647.509ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 183.705ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 182.374ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 144.564ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 196.3ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 178.299ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 206.99ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 69.984ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.877ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 891.248ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 731.815ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 816.007ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 370.376ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 955.047ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 910.022ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 441.585ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 762.687ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 779.701ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 685.875ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 506.733ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 136.189ms
#
# Fitting estimator with 370 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 25.709ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 958.805ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 952.933ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 577.434ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 548.831ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 561.342ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 546.326ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 567.788ms
#
# *** Training of model 'RandomForestClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of classifier ready. Time elapsed: 306.558ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 304.229ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 305.283ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 302.635ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 307.937ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 825.505ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 803.678ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 752.103ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 798.645ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.406ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 204.437ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 179.983ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 297.862ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 949.11ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 776.111ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.194ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 940.345ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 995.714ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 624.868ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 643.807ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# Fitting estimator with 370 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 447.921ms
#
# Fitting estimator with 320 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 392.718ms
#
# Fitting estimator with 270 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 317.368ms
#
# Fitting estimator with 220 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 326.406ms
#
# Fitting estimator with 170 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 98.805ms
#
# Fitting estimator with 120 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 69.44ms
#
# Fitting estimator with 70 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 58.216ms
#
# Fitting estimator with 20 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 28.332ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.514ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.351ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.197ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.499ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.347ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.415ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.246ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 25.64ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 0.893ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.886ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# ...
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 94.228ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 567.129ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 571.653ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 560.096ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 586.593ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 597.72ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 552.408ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 578.846ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 559.829ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 568.279ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 559.077ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 268.284ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 243.689ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 267.198ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 272.916ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 269.25ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# Fitting estimator with 130 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 837.554ms
#
# Fitting estimator with 80 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 575.764ms
#
# Fitting estimator with 30 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 497.366ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 704.469ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 707.845ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 968.571ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 22.122ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 934.649ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 107.552ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 126.562ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 257.988ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 253.414ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 240.901ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 227.566ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 236.008ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 828.024ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 841.117ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 923.007ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 889.491ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 817.108ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 925.558ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 136.675ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 26.551ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 300.995ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 21.55ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 529.016ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 588.17ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 565.548ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 594.474ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 585.385ms
#
# Fitting estimator with 130 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.046ms
#
# Fitting estimator with 80 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.0ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.018ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.152ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.68ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.896ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.738ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.656ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.304ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.269ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.553ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.379ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.452ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.415ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.349ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.614ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.979ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.156ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.861ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.105ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.547ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.186ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.332ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.535ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.451ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.977ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.831ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.725ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.21ms
#
# Fitting estimator with 130 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 167.323ms
#
# Fitting estimator with 80 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 70.198ms
#
# Fitting estimator with 30 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 45.788ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 3.913ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 3.767ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.562ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.552ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.673ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.554ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.578ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 2.639ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 2.437ms
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 2.909ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 2.359ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 2.289ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 3.526ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 3.588ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 7.196ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 3.569ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 7.402ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.7ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 5.194ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 5.016ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.66ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.826ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.308ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.305ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.237ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.64ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 4.716ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7ff418e96278>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 130 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 884.393ms
#
# Fitting estimator with 80 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 622.259ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 328.273ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 319.894ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 512.966ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 519.498ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 500.78ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 488.408ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 510.204ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 92.718ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 92.756ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 87.431ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 87.154ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 92.926ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 582.032ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 599.455ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 581.132ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 589.397ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 640.787ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 602.414ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 611.099ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.7ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pipeline.id
# Out:
# 228
