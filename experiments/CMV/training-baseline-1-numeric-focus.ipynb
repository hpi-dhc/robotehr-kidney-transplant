# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=15)

# %%
feature_pipeline = FeaturePipeline.load(id=19)

# %%
import morpher
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__', 
    'any__Height__', 
    'any__Weight__', 
    'any__VitalSign__', 
    'any__LabValue__', 
]

column_selector = ""
for r in regexes:
    column_selector += r + "|"
column_selector = column_selector[:-1]

# %%
class CustomDataLoader(DataLoader):
    def transform(self, X, y):
        from sklearn.preprocessing import OneHotEncoder
        from enum import Enum

        # remove unused features
        del X['medical_record_number']
        del X['mother_account_number']
        del X['date_of_birth']
        del X['month_of_birth']
        del X['patient_ethnic_group']
        del X['religion']
        del X['address_zip']
        del X['deceased_indicator']
        del X['marital_status_code']

        class RaceType(str, Enum):
            AFRICAN = 'African'
            AMERICAN_BLACK = 'Black or African-American'
            AMERICAN_NATIVE = 'Native American'
            ASIAN = 'Asian'
            ASIAN_PACIFIC = 'Asian Pacific'
            ASIAN_INDIAN = 'Asian Indian'
            ASIAN_CHINESE = 'Asian Chinese'
            HISPANIC = 'Hispanic or Latino'
            OTHER = 'Other'
            WHITE = 'White'

        RACE_MAPPING = {
            RaceType.AFRICAN: [
                'Cape Verdian',
                'Congolese',
                'Eritrean',
                'Ethiopian',
                'Gabonian',
                'Ghanaian',
                'Guinean',
                'Ivory Coastian',
                'Kenyan',
                'Liberian',
                'Madagascar',
                'Malian',
                'Nigerian',
                'Other: East African',
                'Other: North African',
                'Other: South African',
                'Other: West African',
                'Senegalese',
                'Sierra Leonean',
                'Somalian',
                'Sudanese',
                'Tanzanian',
                'Togolese',
                'Ugandan',
                'Zimbabwean'
            ],
            RaceType.AMERICAN_BLACK: [
                'African American (Black)',
                'African-American',
                'Black Or African-American',
                'Black or African - American',
            ],
            RaceType.AMERICAN_NATIVE: [
                'American (Indian/Alaskan)',
                'Native American'
            ],
            RaceType.ASIAN: [
                'Asian',
                'Bangladeshi',
                'Bhutanese',
                'Burmese',
                'Cambodian',
                'Hmong',
                'Indonesian',
                'Japanese',
                'Korean',
                'Laotian',
                'Malaysian',
                'Maldivian',
                'Nepalese',
                'Okinawan',
                'Pakistani',
                'Singaporean',
                'Taiwanese',
                'Thai',
                'Vietnamese',
                'Yapese'
            ],
            RaceType.ASIAN_PACIFIC: [
                'Asian (Pacific Islander)',
                'Carolinian',
                'Chamorro',
                'Chuukese',
                'Fijian',
                'Filipino',
                'Guamanian',
                'Guamanian Or Chamorro',
                'Guamanian or Chamorro',
                'Iwo Jiman',
                'Kiribati',
                'Kosraean',
                'Mariana Islander',
                'Marshallese',
                'Melanesian',
                'Micronesian',
                'Native Hawaiian',
                'New Hebrides',
                'Other Pacific Islander',
                'Pacific Islander',
                'Palauan',
                'Pohnpeian',
                'Polynesian',
                'Saipanese',
                'Samoan',
                'Papua New Guinean',
                'Tahitian',
                'Tokelauan',
                'Tongan'
            ],
            RaceType.ASIAN_INDIAN: [
                'Asian Indian',
                'Sri Lankan',
                'Sri lankan',
                'West Indian'
            ],
            RaceType.ASIAN_CHINESE: [
                'Chinese',
            ],
            RaceType.HISPANIC: [
                'Barbadian',
                'Dominica Islander',
                'Grenadian',
                'Haitian',
                'Hispanic/Latino',
                'Jamaican',
                'St Vincentian',
                'Trinidadian'
            ],
            RaceType.OTHER: [
                '',
                'Aa',
                'Ab',
                'Af',
                'Ag',
                'Ak',
                'Al',
                'Ap',
                'Ar',
                'Av',
                'Ay',
                'B',
                'B1',
                'B2',
                'B3',
                'B4',
                'B5',
                'B6',
                'B7',
                'B8',
                'B9',
                'Ba',
                'Bb',
                'Bc',
                'Bd',
                'Be',
                'Bf',
                'Bg',
                'Bh',
                'Bj',
                'Bk',
                'Bm',
                'Bn',
                'Bo',
                'Bp',
                'Bq',
                'Br',
                'Bs',
                'Bt',
                'Bu',
                'Bv',
                'Bw',
                'Bx',
                'By',
                'Bz',
                'I',
                'MSDW_NOT APPLICABLE',
                'MSDW_OTHER',
                'MSDW_UNKNOWN',
                'NOT AVAILABLE',
                'Non Hispanic',
                'O',
                'Other',
                'Pk',
                'Pl',
                'Pm',
                'Po',
                'Ps',
                'Pv',
                'U',
                'Unk',
                'Unknown',
                'W'
            ],
            RaceType.WHITE: [
                'Caucasian (White)',
                'White'
            ]
        }

        # value mapping
        X['race'] = (
            X.race.map({
                label: cat for cat, labels in RACE_MAPPING.items()
                for label in labels
            }).astype(pd.api.types.CategoricalDtype(RaceType))
        )

        # pre-encoding nan handling
        for column in ['gender', 'race']:
            enc = OneHotEncoder(sparse=False)
            transformed_data = enc.fit_transform(X[[column]])
            transformed_columns = pd.DataFrame(
                data=transformed_data, 
                columns=[f'{column}_{c}' for c in enc.categories_[0]]
            )
            X = X.join(transformed_columns)
            del X[column]
        X[X.columns[X.columns.str.contains('any')]] = X[X.columns[X.columns.str.contains('any')]].fillna(False)
        return X, y
        
    def transform_training_data(self, X_train, y_train):
        from sklearn.impute import SimpleImputer
        imputer = SimpleImputer()
        self.objects['imputer'] = imputer
        X_train_imputed = imputer.fit_transform(X_train)
        
        X_train = pd.DataFrame(
            data=X_train_imputed, 
            columns=X_train.columns,
            index=X_train.index
        )
        return X_train, y_train
    
    def transform_test_data(self, X_test, y_test):
        imputer = self.objects['imputer']
        X_test_imputed = imputer.fit_transform(X_test)
        
        X_test = pd.DataFrame(
            data=X_test_imputed, 
            columns=X_test.columns,
            index=X_test.index
        )
        return X_test, y_test
        

data_loader = CustomDataLoader(column_selector=column_selector)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [(x / 100) for x in range(5, 10, 5)]
observation_windows_occurring = [[x, -1] for x in range(-361, -331, 30)]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator]
targets = ['cytomegaloviral_disease_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-1 CMV + numeric focus',
    version='100.1.2',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric",
    rfe__run=True,
    rfe__step_size=50
)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f762ff75160>
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 193.149ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 818.186ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 477.082ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 113.33ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.127ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 390.8ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 82.357ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 722.72ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 365.881ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 55.929ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 986.572ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 386.746ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 491.994ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 305.599ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 678.808ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 99.7ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 407.312ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 761.539ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 258.294ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 930.572ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 210.726ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 378.963ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 212.964ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 268.08ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 839.488ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 369.06ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 675.903ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 107.174ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 964.718ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 584.926ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 414.364ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 367.704ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 177.25ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 282.263ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 337.63ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 195.65ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 314.782ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.401ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 818.817ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 395.312ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 36.149ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 204.512ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.106ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 688.383ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 388.599ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 152.573ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 398.579ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 251.269ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.418ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 658.356ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 61.71ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 150.833ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 97.316ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 203.447ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 67.186ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 712.538ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 369.147ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 77.848ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 37.007ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 225.274ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 169.406ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 787.812ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 435.883ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 106.136ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 37.455ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 177.341ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 114.056ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 754.304ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 400.053ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 79.16ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.693ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 238.326ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# invalid value encountered in long_scalars
# *** Training of classifier ready. Time elapsed: 105.537ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 719.168ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 412.727ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 115.91ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.776ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 137.687ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 189.022ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 847.458ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 491.589ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 161.618ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 88.673ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 207.324ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# invalid value encountered in long_scalars
# *** Training of classifier ready. Time elapsed: 94.259ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 773.302ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed:
ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.911ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.498ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.326ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.455ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.363ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 20.562ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.652ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.795ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.518ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.33ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.772ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.688ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.385ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.275ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.198ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.944ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.59ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.209ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.834ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.909ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.698ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.112ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.633ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.48ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 15.248ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.344ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.689ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.398ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.228ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 992.348ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 284.674ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 365.244ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.621ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 541.53ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 583.269ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 544.186ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 705.767ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 324.255ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 105.899ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 52.17ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 44.623ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 225.61ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 177.713ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 796.364ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 552.07ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 613.762ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 444.633ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 45.502ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.368ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.156ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 18.592ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 42.398ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 71.534ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# invalid value encountered in long_scalars
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 67.084ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 238.438ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 204.219ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 185.256ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 230.042ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 831.255ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 89.198ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 845.882ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 535.135ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 9.48ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 776.064ms
#
# *** Training of model 'LogisticRegression' started.
# ...
# *** Training of classifier ready. Time elapsed: 12.118ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.76ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.564ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.44ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.898ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.046ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.459ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.526ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.628ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.989ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.016ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.635ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.389ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.056ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 15.38ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.48ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.654ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 37.491ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.453ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.62ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.759ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.097ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 36.557ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.291ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.561ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.629ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.556ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 37.331ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.446ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.62ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.899ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.859ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 40.242ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.945ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.922ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.214ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.588ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 28.563ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.838ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 15.014ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.349ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.557ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.723ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.241ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.293ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.026ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.184ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.381ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.184ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.511ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.913ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.425ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.45ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.35ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.844ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.938ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.257ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.376ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.659ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.947ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.174ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.725ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.934ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 90.286ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 214.634ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 317.887ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 924.201ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 203.91ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 94.313ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 960.055ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 350.383ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 727.27ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 100.867ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 390.485ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 790.703ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 461.52ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 301.142ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 424.891ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 35.046ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.832ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.486ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 32.759ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.116ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# invalid value encountered in long_scalars
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 81.748ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 429.971ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 581.592ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 154.834ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 640.715ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 101.217ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 493.022ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 305.484ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 785.543ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 645.922ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 345.821ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 663.003ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 681.029ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 853.893ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 510.242ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 897.828ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 575.437ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 483.286ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 27.629ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 125.289ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 51.851ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 53.697ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 37.477ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 36.096ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.114ms
#
# *** Training of model 'LogisticRegression' started.
# invalid value encountered in long_scalars
# *** Training of classifier ready. Time elapsed: 917.211ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 743.334ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 319.888ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 85.113ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 90.066ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 759.788ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 346.13ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 165.28ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 765.475ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 221.204ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 284.233ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 684.157ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 667.449ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 599.525ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 181.462ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 861.526ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 842.773ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 453.285ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 109.181ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 147.074ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 6.775ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 68.82ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 73.071ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.935ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 64.189ms
# F-score is ill-defined and being set to 0.0 due to no predicted samples.
# Precision is ill-defined and being set to 0.0 due to no predicted samples.
# invalid value encountered in long_scalars
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 349.128ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 414.526ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 257.713ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 168.377ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 938.639ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 729.544ms
#
# *** Training of model 'LogisticRegression' started.

# %%
pipeline.id
