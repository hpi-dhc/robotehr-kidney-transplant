# %%
# %run ../00_default_options.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle

import matplotlib.pyplot as plt
import shap
import morpher.config
from morpher.plots import plot_feat_importances

from robotehr.api.predictor import get_predictor_details
from robotehr.utils import FriendlyNamesConverter
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # SHAP

# %% [markdown]
# ## UTI

# %%
predictor_uti = get_predictor_details(predictor_id=20, response_type="object")
X_train_uti, X_test_uti, _, _ = train_test_split(
    predictor_uti.get_features(), 
    predictor_uti.get_targets(), 
    test_size=0.2, 
    random_state=0
)

# %%
explainer_uti = shap.KernelExplainer(predictor_uti.clf.predict_proba, X_train_uti, link="logit")
shap_values_uti = explainer_uti.shap_values(X_test_uti, nsamples=100)
# Out:
# HBox(children=(IntProgress(value=0, max=418), HTML(value='')))
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.466e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.560e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.558e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.558e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.555e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.555e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.552e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.552e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.344e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.551e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.549e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.545e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.537e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.531e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.531e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.531e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.522e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.519e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.518e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.517e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.515e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.513e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.513e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.511e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.509e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.508e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.508e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 8.297e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.508e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.502e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.500e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.494e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.491e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.487e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.465e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.445e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.441e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 8.752e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.417e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.410e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.407e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.407e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.384e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.373e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.354e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.324e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 8.560e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.296e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.276e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.593e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.246e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.244e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.215e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.209e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.172e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 6.053e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=5.515e-03, previous alpha=5.168e-03, with an active set of 19 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.466e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=6.120e-03, with an active set of 10 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.561e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.560e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.558e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.558e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.558e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.555e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.555e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.552e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.551e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.549e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.545e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.537e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.531e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.531e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.531e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 9.884e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.522e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.519e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.518e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.517e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.515e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.513e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.513e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.511e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.509e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.508e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.508e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 8.297e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.508e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.502e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 7.885e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.500e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.494e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.491e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.487e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.465e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=5.445e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.441e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 8.752e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.417e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.410e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.407e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.407e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.384e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.373e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.354e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.324e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 8.560e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.296e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=5.276e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 4.593e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.246e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.244e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.215e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.209e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=5.172e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 6.053e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 26 iterations, alpha=5.515e-03, previous alpha=5.168e-03, with an active set of 19 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=5.009e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 94 iterations, i.e. alpha=4.938e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 94 iterations, i.e. alpha=4.886e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 96 iterations, alpha=4.704e-04, previous alpha=4.616e-04, with an active set of 39 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 120 iterations, i.e. alpha=7.387e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 120 iterations, i.e. alpha=7.366e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 120 iterations, i.e. alpha=7.335e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 121 iterations, alpha=7.387e-05, previous alpha=7.271e-05, with an active set of 42 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 63 iterations, i.e. alpha=3.041e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=2.937e-06, with an active set of 50 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.621e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.615e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.615e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 6.144e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.589e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.583e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.575e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.568e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.567e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.561e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.542e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.536e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.530e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.510e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.509e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.487e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.486e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.444e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.363e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.360e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.359e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.346e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.345e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.338e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.330e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.329e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.326e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.323e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.319e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.315e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.301e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.300e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 6.144e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.298e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.287e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.280e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.279e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.272e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.240e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.240e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.239e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.226e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 5.053e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.211e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.210e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.195e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.163e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.146e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.140e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.140e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.113e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.111e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.099e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.097e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.086e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.067e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 5.268e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.067e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.064e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.056e-06, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 68 iterations, alpha=1.621e-06, previous alpha=1.032e-06, with an active set of 51 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=1.866e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=8.879e-06, with an active set of 49 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# ...
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.265e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.344e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.259e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.255e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.225e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.201e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.593e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.195e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.067e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.674e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=3.011e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.987e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.926e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.344e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.873e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.818e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.811e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.803e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.785e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.741e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.683e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.679e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.657e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.619e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.611e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=2.581e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 86 iterations, i.e. alpha=2.471e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 86 iterations, i.e. alpha=2.462e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 87 iterations, alpha=5.357e-05, previous alpha=2.410e-05, with an active set of 46 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=1.797e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.859e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.053e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.844e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.835e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.780e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 6.409e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.670e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.654e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.593e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.619e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.453e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.452e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.445e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 102 iterations, alpha=8.859e-05, previous alpha=8.444e-05, with an active set of 43 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=1.797e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.859e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.053e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.844e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.835e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.780e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 6.409e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.670e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.654e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.593e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.619e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.453e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.452e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 101 iterations, i.e. alpha=8.445e-05, with an active set of 43 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 102 iterations, alpha=8.859e-05, previous alpha=8.444e-05, with an active set of 43 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=6.366e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 29 iterations, i.e. alpha=6.320e-03, with an active set of 21 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 34 iterations, alpha=4.402e-03, previous alpha=4.306e-03, with an active set of 23 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=4.139e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=4.095e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 35 iterations, alpha=4.061e-03, previous alpha=4.053e-03, with an active set of 24 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!

# %%
# what pushes towards negative class
# shap.summary_plot(shap_values_uti[0], X_test_uti)

# %%
columns_uti = {
    'any__Procedure__CPT-4__71020': 'Radiologic chest examination',
    'any__Encounter__Preadmit Testing': 'Preadmit testing',
    'min__labvalue__rbc_blood_cell_from_31_days_before_to_1_days_before': 'Red blood cell count (30d, min)',
    'any__Diagnosis__EPIC__TRANSPLANT ORGAN OFFER': 'Transplant organ offer',
    'any__Diagnosis__ICD-10__N18.6': 'End-stage renal disease', 
    'gender_Female': 'Female gender',
    'min__labvalue__ventricular_rate_from_31_days_before_to_1_days_before': 'Ventricular rate (30d, min)',
    'any__Diagnosis__ICD-10__R06.02': 'Shortness of breath',
    'min__labvalue__protein_total-bld_from_31_days_before_to_1_days_before': 'Total protein (blood, 30d, min)',
    'any__Procedure__Cardiac Cath Performed__LV Angiography': 'Left heart ventricular angiopathy',
}
#columns_uti = {}

# %%
# what pushes towards positive class
shap.summary_plot(shap_values_uti[1], X_test_uti.rename(columns=columns_uti), max_display=10,show=False)

# %%
pickle.dump(
    {'shap_values': shap_values_uti, 'X_test': X_test_uti.rename(columns=columns_uti)}, 
    open('/home/martet02/shap-uti.pickle', 'wb')
)

# %%
! python /home/martet02/kidney-transplant-data/scripts/shap-values.py uti
# Out:
# Done

# %% [markdown]
# ## CMV

# %%
predictor_cmv = get_predictor_details(predictor_id=17, response_type="object")
X_train_cmv, X_test_cmv, _, _ = train_test_split(
    predictor_cmv.get_features(), 
    predictor_cmv.get_targets(), 
    test_size=0.2, 
    random_state=42
)

# %%
explainer_cmv = shap.KernelExplainer(predictor_cmv.clf.predict_proba, X_train_cmv, link="logit")
shap_values_cmv = explainer_cmv.shap_values(X_test_cmv, nsamples=100)
# Out:
# HBox(children=(IntProgress(value=0, max=418), HTML(value='')))
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.385e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=1.361e-02, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=6.927e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 56 iterations, alpha=6.912e-03, previous alpha=6.901e-03, with an active set of 35 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.385e-02, with an active set of 25 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=6.927e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=6.927e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 56 iterations, alpha=6.912e-03, previous alpha=6.901e-03, with an active set of 35 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.048e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.320e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=3.284e-03, previous alpha=3.219e-03, with an active set of 12 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=1.048e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=3.320e-03, with an active set of 12 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 15 iterations, alpha=3.284e-03, previous alpha=3.219e-03, with an active set of 12 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 102 iterations, i.e. alpha=1.269e-04, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=4.348e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=4.338e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=4.290e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 6.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=4.284e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=4.256e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 9.771e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 112 iterations, i.e. alpha=4.068e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.758e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.755e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.750e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.738e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.733e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.730e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 8.025e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.728e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.707e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 7.743e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.676e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.666e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.628e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.607e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 6.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.604e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 6.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.590e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.585e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.575e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.524e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.511e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.507e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.472e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.397e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.338e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 8.429e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.328e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.260e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 114 iterations, i.e. alpha=3.228e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 115 iterations, alpha=3.891e-05, previous alpha=3.204e-05, with an active set of 48 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 94 iterations, i.e. alpha=6.463e-04, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.231e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.231e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.229e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.229e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.227e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.225e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.225e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.223e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.593e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.223e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.223e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.223e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.223e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.222e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.221e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.221e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=3.220e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 105 iterations, alpha=3.231e-04, previous alpha=3.218e-04, with an active set of 42 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.716e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.046e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=5.857e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=5.829e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 112 iterations, alpha=5.857e-03, previous alpha=5.776e-03, with an active set of 29 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=2.868e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.854e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.457e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.457e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 40 iterations, alpha=2.411e-03, previous alpha=2.336e-03, with an active set of 27 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=4.694e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=4.676e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=4.676e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=4.532e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=4.496e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 63 iterations, alpha=4.676e-04, previous alpha=4.468e-04, with an active set of 38 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 1 iterations, i.e. alpha=1.588e-01, with an active set of 1 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.354e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=6.769e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 71 iterations, alpha=6.765e-02, previous alpha=6.762e-02, with an active set of 24 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.354e-01, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=6.769e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=6.769e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=6.768e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 69 iterations, alpha=6.767e-02, previous alpha=6.761e-02, with an active set of 24 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=8.821e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 92 iterations, i.e. alpha=4.526e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.268e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 92 iterations, i.e. alpha=4.472e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=4.524e-05, previous alpha=4.458e-05, with an active set of 49 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=2.686e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=7.756e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=7.671e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 5.771e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=7.547e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=7.446e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=7.414e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=7.386e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=7.382e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 63 iterations, alpha=7.718e-04, previous alpha=7.207e-04, with an active set of 30 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.109e-04, with an active set of 41 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.096e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.079e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.066e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.034e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.007e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.006e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.923e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.834e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.826e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.769e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.750e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.618e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 6.409e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.600e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 7.451e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.583e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.527e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.474e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.278e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.111e-05, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=8.835e-05, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=8.744e-05, with an active set of 44 regressors, and the smallest cholesky pivot element being 7.300e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=8.319e-05, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=8.110e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=8.095e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=8.075e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=8.051e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=7.995e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=7.808e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=7.701e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=7.601e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=7.589e-05, with an active set of 46 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.520e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.497e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.394e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.393e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.329e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.220e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.172e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.050e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=6.956e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=6.894e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=6.881e-05, with an active set of 47 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.699e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.546e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 6.144e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.448e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.420e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.399e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.328e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.314e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.288e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.275e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.255e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.236e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.229e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.198e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.136e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.119e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.108e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.068e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.057e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.029e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.972e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.920e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.857e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.857e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.781e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.778e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.709e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.666e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.655e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.641e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=5.615e-05, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# ...
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=3.006e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=1.407e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 53 iterations, i.e. alpha=4.424e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 7.451e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=4.166e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=4.008e-04, with an active set of 36 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=3.986e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=3.884e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 6.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=3.826e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 9.424e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.765e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.756e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.731e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 8.025e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.684e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.678e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.677e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.658e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 9.064e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.612e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.610e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.583e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=3.572e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 9.541e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 59 iterations, alpha=4.166e-04, previous alpha=3.516e-04, with an active set of 38 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=4.094e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 99 iterations, alpha=1.172e-03, previous alpha=1.172e-03, with an active set of 36 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=1.415e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=1.381e-03, with an active set of 29 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.925e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.914e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.912e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.905e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.890e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.883e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.873e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 71 iterations, i.e. alpha=6.859e-04, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 72 iterations, alpha=6.925e-04, previous alpha=6.626e-04, with an active set of 35 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=1.135e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 103 iterations, i.e. alpha=4.019e-04, with an active set of 41 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 104 iterations, alpha=4.013e-04, previous alpha=3.998e-04, with an active set of 41 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=2.253e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=8.502e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 7.146e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=8.494e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=8.444e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=8.421e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=8.396e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 8.229e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=8.499e-04, previous alpha=8.328e-04, with an active set of 38 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=4.241e-03, with an active set of 28 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=3.634e-03, with an active set of 33 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=3.564e-03, previous alpha=3.555e-03, with an active set of 34 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=2.651e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 58 iterations, i.e. alpha=2.633e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=1.326e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=1.319e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 76 iterations, alpha=1.300e-03, previous alpha=1.293e-03, with an active set of 31 regressors.

# %%
# what pushes towards negative class
# shap.summary_plot(shap_values_cmv[0], X_test_cmv)

# %%
columns_cmv = {
    'any__Diagnosis__ICD-10__N18.4': 'Chronic kidney disease',
    'any__Diagnosis__EPIC__ESTABLISHED PATIENT / CHRONIC PROBLEM': 'Chronic illness',
    'any__Diagnosis__ICD-10__I10': 'Essential hypertension',
    'min__labvalue__nrbc#_from_31_days_before_to_1_days_before': 'Nucleated red blood cells \# (30d, min)',
    'race_Hispanic or Latino': 'Hispanic ethnicity',
    'any__Diagnosis__ICD-9__R69': 'Unspecified illness',
    'any__Diagnosis__ICD-10__D63.1': 'Anemia in CKD',
    'any__Diagnosis__APRDRG MDC__011': 'Kidney \& urin tract diseases',
    'any__Diagnosis__ICD-10__N18.6': 'End-stage renal disease',
    'any__Diagnosis__IMO__4908': 'Benign hypertension'
}

# %%
# what pushes towards positive class
shap.summary_plot(shap_values_cmv[1], X_test_cmv.rename(columns=columns_cmv), max_display=10,show=False)

# %%
pickle.dump(
    {'shap_values': shap_values_cmv, 'X_test': X_test_cmv.rename(columns=columns_cmv)}, 
    open('/home/martet02/shap-cmv.pickle', 'wb')
)

# %%
! python /home/martet02/kidney-transplant-data/scripts/shap-values.py cmv
# Out:
# Done

# %% [markdown]
# ## OVI

# %%
predictor_ovi = get_predictor_details(predictor_id=19, response_type="object")
X_train_ovi, X_test_ovi ,_ ,_ = train_test_split(
    predictor_ovi.get_features(), 
    predictor_ovi.get_targets(), 
    test_size=0.2, 
    random_state=37
)

# %%
explainer_ovi = shap.KernelExplainer(predictor_ovi.clf.predict_proba, X_train_ovi, link="logit")
shap_values_ovi = explainer_ovi.shap_values(X_test_ovi, nsamples=100)
# Out:
# HBox(children=(IntProgress(value=0, max=418), HTML(value='')))
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=9.597e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 187 iterations, alpha=3.284e-02, previous alpha=3.284e-02, with an active set of 32 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=9.597e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 187 iterations, alpha=3.284e-02, previous alpha=3.284e-02, with an active set of 32 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.432e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.407e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=6.321e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 9.996e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=5.966e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 7.814e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=6.321e-04, previous alpha=5.929e-04, with an active set of 43 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=1.431e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.405e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=6.310e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 9.996e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=5.958e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 7.814e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=6.310e-04, previous alpha=5.926e-04, with an active set of 43 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=8.984e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.482e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.481e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.481e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.480e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.479e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.478e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 5.268e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.477e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.477e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.476e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.476e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.475e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.473e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 8.560e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.472e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.472e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.471e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.470e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.470e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.470e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.468e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.468e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 6.580e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.467e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.466e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.464e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 5.268e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.463e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=4.461e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.461e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.460e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.460e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 7.146e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.459e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.458e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.457e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.457e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.456e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 7.525e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.456e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.454e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.454e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.453e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.453e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.453e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.450e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.450e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.449e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.449e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.449e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.447e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.447e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.446e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.445e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.445e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.444e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.443e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.442e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 9.996e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.441e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.440e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.439e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.439e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.439e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.439e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.867e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.438e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.437e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.436e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.436e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.436e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.436e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.435e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 6.664e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.434e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.434e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.434e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 9.306e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.432e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.430e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.429e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.428e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.428e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 7.743e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.426e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 8.689e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.425e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.425e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.424e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.423e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.423e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.422e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.420e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.420e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.419e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.418e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 5.268e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.418e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.416e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.414e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.412e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 7.671e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.412e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.344e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.410e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.410e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=4.408e-02, with an active set of 24 regressors, and the smallest cholesky pivot element being 8.093e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 99 iterations, alpha=4.481e-02, previous alpha=4.407e-02, with an active set of 24 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=5.517e-03, with an active set of 18 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 79 iterations, i.e. alpha=1.745e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 80 iterations, alpha=1.743e-03, previous alpha=1.739e-03, with an active set of 31 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=5.365e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 49 iterations, i.e. alpha=1.760e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 49 iterations, i.e. alpha=1.760e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=1.583e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=1.582e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 54 iterations, alpha=1.499e-03, previous alpha=1.475e-03, with an active set of 33 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.043e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 49 iterations, i.e. alpha=2.654e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 90 iterations, i.e. alpha=1.498e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 91 iterations, alpha=1.498e-03, previous alpha=1.481e-03, with an active set of 36 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=3.161e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 45 iterations, alpha=3.146e-03, previous alpha=3.131e-03, with an active set of 26 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 65 iterations, i.e. alpha=1.866e-05, with an active set of 41 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.006e-05, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=1.002e-05, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.945e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.885e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.884e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.869e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.785e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.657e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.652e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.599e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.412e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.323e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.295e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.176e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=9.030e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.999e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.947e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.532e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.454e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.446e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.386e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.351e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 7.451e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.313e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.263e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.263e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.260e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.250e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.109e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 5.576e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=8.034e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 68 iterations, i.e. alpha=7.954e-06, with an active set of 44 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.804e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.960e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.725e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.725e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.634e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.593e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.582e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.568e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.538e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 7.743e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.532e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.520e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.446e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.383e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.371e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.356e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 69 iterations, i.e. alpha=7.362e-06, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 70 iterations, alpha=9.948e-06, previous alpha=7.326e-06, with an active set of 45 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=5.410e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 60 iterations, alpha=5.401e-04, previous alpha=5.304e-04, with an active set of 37 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=1.668e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=7.096e-03, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# ...
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.917e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.863e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.660e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.630e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.580e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.363e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.302e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 111 iterations, i.e. alpha=1.210e-07, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.221e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=7.023e-04, with an active set of 32 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=7.001e-04, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=6.945e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=6.932e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=6.928e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 106 iterations, alpha=7.019e-04, previous alpha=6.884e-04, with an active set of 33 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.221e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=7.023e-04, with an active set of 32 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 104 iterations, i.e. alpha=7.001e-04, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=6.945e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=6.932e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=6.928e-04, with an active set of 33 regressors, and the smallest cholesky pivot element being 6.234e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 106 iterations, alpha=7.019e-04, previous alpha=6.884e-04, with an active set of 33 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=3.627e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=2.354e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.844e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.842e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.838e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.780e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.778e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.566e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.553e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 4.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.549e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.537e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.516e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.504e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.489e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 5.674e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.487e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=1.566e-04, previous alpha=1.477e-04, with an active set of 31 regressors.
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=3.627e-04, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 33 iterations, i.e. alpha=2.354e-04, with an active set of 29 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.844e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.842e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.838e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.780e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=1.778e-04, with an active set of 30 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.566e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.553e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 4.829e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.549e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.537e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.516e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.504e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 6.322e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.489e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 5.674e-08. Reduce max_iter or increase eps parameters.
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=1.487e-04, with an active set of 31 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 38 iterations, alpha=1.566e-04, previous alpha=1.477e-04, with an active set of 31 regressors.

# %%
# what pushes towards negative class
# shap.summary_plot(shap_values_ovi[0], X_test_ovi)

# %%
columns_ovi = {
    'any__Diagnosis__ICD-9__070.54': 'Chronic hepatitis C',
    'max__labvalue__monocyte_%_from_31_days_before_to_1_days_before': 'Monocyte \% (30d, max)',
    'max__weight__weight_from_31_days_before_to_1_days_before': 'Weight (30d, max)',
    'min__labvalue__monocyte_%_from_331_days_before_to_301_days_before': 'Monocyte \% (330-300d, min)',
    'min__labvalue__white_blood_cell_from_211_days_before_to_181_days_before': 'White blood cell (210-180d, min)',
    'max__labvalue__ast_(sgot)_from_31_days_before_to_1_days_before': 'Aspartate aminotransferase (30d, max)',
    'min__labvalue__ast_(sgot)_from_181_days_before_to_151_days_before': 'Aspartate aminotransferase (180-150d, min)',
    'min__vitalsign__ibex__(t-t)_from_31_days_before_to_1_days_before': 'Tympanic temperature (30d, min)',
    'max__labvalue__pro_time_from_31_days_before_to_1_days_before': 'Prothrombin time (30d, max)',
    'max__labvalue__alt(sgpt)_from_31_days_before_to_1_days_before': 'Alanine transaminase (30d, max)'
}

# %%
# what pushes towards positive class
shap.summary_plot(shap_values_ovi[1], X_test_ovi.rename(columns=columns_ovi), max_display=10,show=False,plot_size=[4,4])

# %%
pickle.dump(
    {'shap_values': shap_values_ovi, 'X_test': X_test_ovi.rename(columns=columns_ovi)}, 
    open('/home/martet02/shap-ovi.pickle', 'wb')
)

# %%
! python /home/martet02/kidney-transplant-data/scripts/shap-values.py ovi
# Out:
# Done

# %% [markdown]
# # VIOLINS

# %%
from robotehr.evaluation.risk_groups import make_risk_groups, plot_risk_groups
from robotehr.models.predictor import Predictor

# %%
predictor_uti = Predictor.load(id=20)
predictor_ovi = Predictor.load(id=19)
predictor_cmv = Predictor.load(id=17)

# %%
# must be defined for legacy reasons
regexes = [
    'any__Diagnosis__',
    'any__Procedure__', 
    'any__Drug__', 
    'any__Material__', 
    'any__Encounter__', 
    'any__AlcoholUse__', 
    'any__DrugUse__', 
    'any__TobaccoUse__',
    'min__height__', 
    'min__weight__', 
    'min__vitalsign__', 
    'min__measurement__', 
    'min__labvalue__', 
    'max__height__', 
    'max__weight__', 
    'max__vitalsign__', 
    'max__measurement__', 
    'max__labvalue__'
]

column_selector = ""
for r in regexes:
    column_selector += r + "|"
column_selector = column_selector[:-1]

class CustomDataLoader(DataLoader):
    def transform(self, X, y):
        from sklearn.preprocessing import OneHotEncoder
        from enum import Enum

        # remove unused features
        del X['medical_record_number']
        del X['mother_account_number']
        del X['date_of_birth']
        del X['month_of_birth']
        del X['patient_ethnic_group']
        del X['religion']
        del X['address_zip']
        del X['deceased_indicator']
        del X['marital_status_code']

        class RaceType(str, Enum):
            AFRICAN = 'African'
            AMERICAN_BLACK = 'Black or African-American'
            AMERICAN_NATIVE = 'Native American'
            ASIAN = 'Asian'
            ASIAN_PACIFIC = 'Asian Pacific'
            ASIAN_INDIAN = 'Asian Indian'
            ASIAN_CHINESE = 'Asian Chinese'
            HISPANIC = 'Hispanic or Latino'
            OTHER = 'Other'
            WHITE = 'White'

        RACE_MAPPING = {
            RaceType.AFRICAN: [
                'Cape Verdian',
                'Congolese',
                'Eritrean',
                'Ethiopian',
                'Gabonian',
                'Ghanaian',
                'Guinean',
                'Ivory Coastian',
                'Kenyan',
                'Liberian',
                'Madagascar',
                'Malian',
                'Nigerian',
                'Other: East African',
                'Other: North African',
                'Other: South African',
                'Other: West African',
                'Senegalese',
                'Sierra Leonean',
                'Somalian',
                'Sudanese',
                'Tanzanian',
                'Togolese',
                'Ugandan',
                'Zimbabwean'
            ],
            RaceType.AMERICAN_BLACK: [
                'African American (Black)',
                'African-American',
                'Black Or African-American',
                'Black or African - American',
            ],
            RaceType.AMERICAN_NATIVE: [
                'American (Indian/Alaskan)',
                'Native American'
            ],
            RaceType.ASIAN: [
                'Asian',
                'Bangladeshi',
                'Bhutanese',
                'Burmese',
                'Cambodian',
                'Hmong',
                'Indonesian',
                'Japanese',
                'Korean',
                'Laotian',
                'Malaysian',
                'Maldivian',
                'Nepalese',
                'Okinawan',
                'Pakistani',
                'Singaporean',
                'Taiwanese',
                'Thai',
                'Vietnamese',
                'Yapese'
            ],
            RaceType.ASIAN_PACIFIC: [
                'Asian (Pacific Islander)',
                'Carolinian',
                'Chamorro',
                'Chuukese',
                'Fijian',
                'Filipino',
                'Guamanian',
                'Guamanian Or Chamorro',
                'Guamanian or Chamorro',
                'Iwo Jiman',
                'Kiribati',
                'Kosraean',
                'Mariana Islander',
                'Marshallese',
                'Melanesian',
                'Micronesian',
                'Native Hawaiian',
                'New Hebrides',
                'Other Pacific Islander',
                'Pacific Islander',
                'Palauan',
                'Pohnpeian',
                'Polynesian',
                'Saipanese',
                'Samoan',
                'Papua New Guinean',
                'Tahitian',
                'Tokelauan',
                'Tongan'
            ],
            RaceType.ASIAN_INDIAN: [
                'Asian Indian',
                'Sri Lankan',
                'Sri lankan',
                'West Indian'
            ],
            RaceType.ASIAN_CHINESE: [
                'Chinese',
            ],
            RaceType.HISPANIC: [
                'Barbadian',
                'Dominica Islander',
                'Grenadian',
                'Haitian',
                'Hispanic/Latino',
                'Jamaican',
                'St Vincentian',
                'Trinidadian'
            ],
            RaceType.OTHER: [
                '',
                'Aa',
                'Ab',
                'Af',
                'Ag',
                'Ak',
                'Al',
                'Ap',
                'Ar',
                'Av',
                'Ay',
                'B',
                'B1',
                'B2',
                'B3',
                'B4',
                'B5',
                'B6',
                'B7',
                'B8',
                'B9',
                'Ba',
                'Bb',
                'Bc',
                'Bd',
                'Be',
                'Bf',
                'Bg',
                'Bh',
                'Bj',
                'Bk',
                'Bm',
                'Bn',
                'Bo',
                'Bp',
                'Bq',
                'Br',
                'Bs',
                'Bt',
                'Bu',
                'Bv',
                'Bw',
                'Bx',
                'By',
                'Bz',
                'I',
                'MSDW_NOT APPLICABLE',
                'MSDW_OTHER',
                'MSDW_UNKNOWN',
                'NOT AVAILABLE',
                'Non Hispanic',
                'O',
                'Other',
                'Pk',
                'Pl',
                'Pm',
                'Po',
                'Ps',
                'Pv',
                'U',
                'Unk',
                'Unknown',
                'W'
            ],
            RaceType.WHITE: [
                'Caucasian (White)',
                'White'
            ]
        }

        # value mapping
        X['race'] = (
            X.race.map({
                label: cat for cat, labels in RACE_MAPPING.items()
                for label in labels
            }).astype(pd.api.types.CategoricalDtype(RaceType))
        )

        # pre-encoding nan handling
        for column in ['gender', 'race']:
            enc = OneHotEncoder(sparse=False)
            transformed_data = enc.fit_transform(X[[column]])
            transformed_columns = pd.DataFrame(
                data=transformed_data, 
                columns=[f'{column}_{c}' for c in enc.categories_[0]]
            )
            X = X.join(transformed_columns)
            del X[column]
        X[X.columns[X.columns.str.contains('any')]] = X[X.columns[X.columns.str.contains('any')]].fillna(False)
        return X, y
        
    def transform_training_data(self, X_train, y_train):
        from sklearn.preprocessing import StandardScaler
        scaler = StandardScaler()
        self.objects['scaler'] = scaler
        X_train_scaled = scaler.fit_transform(X_train)
        
        from sklearn.impute import SimpleImputer
        imputer = SimpleImputer()
        self.objects['imputer'] = imputer
        X_train_imputed = imputer.fit_transform(X_train_scaled)
        
        X_train = pd.DataFrame(
            data=X_train_imputed, 
            columns=X_train.columns,
            index=X_train.index
        )
        return X_train, y_train
    
    def transform_test_data(self, X_test, y_test):
        scaler = self.objects['scaler']
        imputer = self.objects['imputer']
        X_test_scaled = scaler.transform(X_test)
        X_test_imputed = imputer.fit_transform(X_test_scaled)
        
        X_test = pd.DataFrame(
            data=X_test_imputed, 
            columns=X_test.columns,
            index=X_test.index
        )
        return X_test, y_test
        
data_loader = CustomDataLoader(column_selector=column_selector)

# %%
# for the future (when with pipeline with separated preprocessing)
# from robotehr.pipelines.supporters.preprocessing import DataLoader
# data_loader = DataLoader.load(predictor_uti.training_configuration.training_pipeline.data_loader_path)

# %%
df_uti = make_risk_groups(predictor_uti, data_loader)
df_cmv = make_risk_groups(predictor_cmv, data_loader)
df_ovi = make_risk_groups(predictor_ovi, data_loader)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f96c3afd940>
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f96c8d64518>
# Fetching data for Patient (...)
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f96c38ed978>
# Fetching data for Patient (...)

# %%
plt.rcParams['text.usetex'] = True 
plt.rcParams['text.latex.preamble'] = [r'\usepackage[cm]{sfmath}']
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'cm'
plt.rcParams['font.size'] = 14

# %%
plot_risk_groups(
    df=df_uti, 
    features=list(columns_uti)[:6], 
    friendly_names_converter=dict([[k, columns_uti[k]] for k in list(columns_uti)[:6]]),
    filename="/home/martet02/figures/new-violins-uti.pdf",
).show()

# %%
temp_columns_cmv = {
    'any__Diagnosis__ICD-10__N18.4': 'Chronic kidney disease',
    'any__Diagnosis__EPIC__ESTABLISHED PATIENT / CHRONIC PROBLEM': 'Chronic illness',
    'any__Diagnosis__ICD-10__I10': 'Essential hypertension',
    #'min__labvalue__nrbc#_from_31_days_before_to_1_days_before': 'Nucleated red blood cells \# (30d, min)',
    #'race_Hispanic or Latino': 'Hispanic ethnicity',
    'any__Diagnosis__ICD-9__R69': 'Unspecified illness',
    'any__Diagnosis__ICD-10__D63.1': 'Anemia in CKD',
    'any__Diagnosis__APRDRG MDC__011': 'Kidney \& urin tract diseases',
    'any__Diagnosis__ICD-10__N18.6': 'End-stage renal disease',
    'any__Diagnosis__IMO__4908': 'Benign hypertension'
}
plot_risk_groups(
    df=df_cmv, 
    features=list(temp_columns_cmv)[:6], 
    friendly_names_converter=dict([[k, temp_columns_cmv[k]] for k in list(temp_columns_cmv)[:6]]),
    filename="/home/martet02/figures/new-violins-cmv.pdf",
).show()

# %%
plot_risk_groups(
    df=df_ovi, 
    features=list(columns_ovi)[:6], 
    friendly_names_converter=dict([[k, columns_ovi[k]] for k in list(columns_ovi)[:6]]),
    filename="/home/martet02/figures/new-violins-ovi.pdf"
).show()
