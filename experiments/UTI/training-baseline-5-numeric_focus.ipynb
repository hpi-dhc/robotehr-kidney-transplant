# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.api.training import get_training_results
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader
# Out:
# [2020-05-31 14:41:51,336] INFO in __init__: RobotEHR API

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=17)

# %%
feature_pipeline = FeaturePipeline.load(id=22)

# %%
import morpher.config
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__',
    #'any__Procedure__', 
    #'any__Drug__', 
    #'any__Material__', 
    #'any__Encounter__', 
    #'any__AlcoholUse__', 
    #'any__DrugUse__', 
    #'any__TobaccoUse__',
]

agg_func_regex = ""
for r in regexes:
    agg_func_regex += r + "|"
agg_func_regex = agg_func_regex[:-1]

def prepare_data_function(data, target):
    import morpher
    from morpher.jobs import Impute, Scale
    from sklearn.preprocessing import OneHotEncoder
    from enum import Enum
    
    # remove unused features
    del data['medical_record_number']
    del data['mother_account_number']
    del data['date_of_birth']
    del data['month_of_birth']
    del data['patient_ethnic_group']
    del data['religion']
    del data['address_zip']
    del data['deceased_indicator']
    del data['marital_status_code']
    
    class RaceType(str, Enum):
        AFRICAN = 'African'
        AMERICAN_BLACK = 'Black or African-American'
        AMERICAN_NATIVE = 'Native American'
        ASIAN = 'Asian'
        ASIAN_PACIFIC = 'Asian Pacific'
        ASIAN_INDIAN = 'Asian Indian'
        ASIAN_CHINESE = 'Asian Chinese'
        HISPANIC = 'Hispanic or Latino'
        OTHER = 'Other'
        WHITE = 'White'
    
    RACE_MAPPING = {
        RaceType.AFRICAN: [
            'Cape Verdian',
            'Congolese',
            'Eritrean',
            'Ethiopian',
            'Gabonian',
            'Ghanaian',
            'Guinean',
            'Ivory Coastian',
            'Kenyan',
            'Liberian',
            'Madagascar',
            'Malian',
            'Nigerian',
            'Other: East African',
            'Other: North African',
            'Other: South African',
            'Other: West African',
            'Senegalese',
            'Sierra Leonean',
            'Somalian',
            'Sudanese',
            'Tanzanian',
            'Togolese',
            'Ugandan',
            'Zimbabwean'
        ],
        RaceType.AMERICAN_BLACK: [
            'African American (Black)',
            'African-American',
            'Black Or African-American',
            'Black or African - American',
        ],
        RaceType.AMERICAN_NATIVE: [
            'American (Indian/Alaskan)',
            'Native American'
        ],
        RaceType.ASIAN: [
            'Asian',
            'Bangladeshi',
            'Bhutanese',
            'Burmese',
            'Cambodian',
            'Hmong',
            'Indonesian',
            'Japanese',
            'Korean',
            'Laotian',
            'Malaysian',
            'Maldivian',
            'Nepalese',
            'Okinawan',
            'Pakistani',
            'Singaporean',
            'Taiwanese',
            'Thai',
            'Vietnamese',
            'Yapese'
        ],
        RaceType.ASIAN_PACIFIC: [
            'Asian (Pacific Islander)',
            'Carolinian',
            'Chamorro',
            'Chuukese',
            'Fijian',
            'Filipino',
            'Guamanian',
            'Guamanian Or Chamorro',
            'Guamanian or Chamorro',
            'Iwo Jiman',
            'Kiribati',
            'Kosraean',
            'Mariana Islander',
            'Marshallese',
            'Melanesian',
            'Micronesian',
            'Native Hawaiian',
            'New Hebrides',
            'Other Pacific Islander',
            'Pacific Islander',
            'Palauan',
            'Pohnpeian',
            'Polynesian',
            'Saipanese',
            'Samoan',
            'Papua New Guinean',
            'Tahitian',
            'Tokelauan',
            'Tongan'
        ],
        RaceType.ASIAN_INDIAN: [
            'Asian Indian',
            'Sri Lankan',
            'Sri lankan',
            'West Indian'
        ],
        RaceType.ASIAN_CHINESE: [
            'Chinese',
        ],
        RaceType.HISPANIC: [
            'Barbadian',
            'Dominica Islander',
            'Grenadian',
            'Haitian',
            'Hispanic/Latino',
            'Jamaican',
            'St Vincentian',
            'Trinidadian'
        ],
        RaceType.OTHER: [
            '',
            'Aa',
            'Ab',
            'Af',
            'Ag',
            'Ak',
            'Al',
            'Ap',
            'Ar',
            'Av',
            'Ay',
            'B',
            'B1',
            'B2',
            'B3',
            'B4',
            'B5',
            'B6',
            'B7',
            'B8',
            'B9',
            'Ba',
            'Bb',
            'Bc',
            'Bd',
            'Be',
            'Bf',
            'Bg',
            'Bh',
            'Bj',
            'Bk',
            'Bm',
            'Bn',
            'Bo',
            'Bp',
            'Bq',
            'Br',
            'Bs',
            'Bt',
            'Bu',
            'Bv',
            'Bw',
            'Bx',
            'By',
            'Bz',
            'I',
            'MSDW_NOT APPLICABLE',
            'MSDW_OTHER',
            'MSDW_UNKNOWN',
            'NOT AVAILABLE',
            'Non Hispanic',
            'O',
            'Other',
            'Pk',
            'Pl',
            'Pm',
            'Po',
            'Ps',
            'Pv',
            'U',
            'Unk',
            'Unknown',
            'W'
        ],
        RaceType.WHITE: [
            'Caucasian (White)',
            'White'
        ]
    }
    
    # value mapping
    data['race'] = (
        data.race.map({
            label: cat for cat, labels in RACE_MAPPING.items()
            for label in labels
        }).astype(pd.api.types.CategoricalDtype(RaceType))
    )
    
    # pre-encoding nan handling
    for column in ['gender', 'race']:
        enc = OneHotEncoder(sparse=False)
        transformed_data = enc.fit_transform(data[[column]])
        transformed_columns = pd.DataFrame(
            data=transformed_data, 
            columns=[f'{column}_{c}' for c in enc.categories_[0]]
        )
        data = data.join(transformed_columns)
        del data[column]
        
    label_encoded_data = data.copy()
    
    label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]] = label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]].fillna(False)
    
    scaled_data, _ = Scale().execute(data=label_encoded_data, target=target)
    
    imputed_data, _ = Impute().execute(data=scaled_data, imputation_method=morpher.config.imputers.DEFAULT)
    
    return imputed_data

data_loader = DataLoader(agg_func_regex, prepare_data_function)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [0.05]
observation_windows_occurring = [[-361, -1]]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator]
targets = ['urinary_tract_infection_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.BORDERLINE, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-5 uti time series + numeric focus',
    version='15.0.0',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric_time_series",
    rfe__run=True,
    rfe__step_size=50
)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fe5d26a3198>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 372 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 615.951ms
#
# Fitting estimator with 322 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 296.026ms
#
# Fitting estimator with 272 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 25.377ms
#
# Fitting estimator with 222 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 662.152ms
#
# Fitting estimator with 172 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 345.045ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 56.838ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.208ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 222.227ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 146.45ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 142.301ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 238.186ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 200.476ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 660.476ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 609.999ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 666.909ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 665.011ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 661.121ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 302.268ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 337.028ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 393.333ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 368.269ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 382.279ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 420.794ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 359.545ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 292.815ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 317.354ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 370.952ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 847.731ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 856.727ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 771.992ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 831.257ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 844.454ms
#
# Fitting estimator with 372 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 75.005ms
#
# Fitting estimator with 322 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.638ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 970.48ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 953.498ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 27.352ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 75.367ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 27.927ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 49.966ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.193ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 588.552ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 617.313ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 606.405ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 581.501ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 593.992ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 251.936ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 299.787ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 261.456ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 258.58ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 301.102ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 250.704ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 249.776ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 300.908ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 239.443ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 223.767ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 838.406ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 852.304ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 790.611ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 828.57ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 797.501ms
#
# Fitting estimator with 372 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 36.659ms
#
# Fitting estimator with 322 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.082ms
#
# Fitting estimator with 272 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 24.808ms
#
# Fitting estimator with 222 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 20.131ms
#
# Fitting estimator with 172 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.923ms
#
# Fitting estimator with 122 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.058ms
#
# Fitting estimator with 72 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 7.686ms
#
# Fitting estimator with 22 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.244ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.352ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.33ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.432ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.419ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.651ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.359ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.566ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.181ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.123ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.087ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.007ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.232ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.296ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.288ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.981ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.2ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.258ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.072ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.753ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.661ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.984ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.743ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.738ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.742ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.039ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.115ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.368ms
#
# Fitting estimator with 372 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 186.983ms
#
# Fitting estimator with 322 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 169.219ms
#
# Fitting estimator with 272 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 123.68ms
#
# Fitting estimator with 222 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 130.766ms
#
# Fitting estimator with 172 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 109.621ms
#
# Fitting estimator with 122 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 86.919ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 69.466ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 83.323ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 90.03ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 81.14ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 123.801ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 79.138ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 97.143ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 69.599ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 67.543ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 50.85ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 67.332ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 50.146ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 98.64ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 107.52ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 85.266ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 103.642ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 85.46ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 92.077ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 91.655ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 78.407ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 77.908ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 85.937ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 65.021ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 74.047ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 87.334ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 67.872ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 75.035ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fe5d20c4b38>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 372 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 552.136ms
#
# Fitting estimator with 322 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 221.511ms
#
# Fitting estimator with 272 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 915.52ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 635.734ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 571.855ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 952.916ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 905.054ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 956.223ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 865.74ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 943.069ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.501ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 926.573ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 964.434ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 948.062ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 955.644ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 167.769ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 166.328ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 201.853ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 112.828ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 250.691ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 172.061ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 238.232ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 141.071ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 127.403ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 180.757ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 295.041ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 310.067ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 270.272ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 254.975ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 276.705ms
#
# Fitting estimator with 372 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 974.44ms
#
# Fitting estimator with 322 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 974.445ms
#
# Fitting estimator with 272 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 986.829ms
#
# Fitting estimator with 222 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 961.84ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 967.439ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 906.021ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 980.288ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 955.637ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 979.356ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 974.495ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.819ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 594.038ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 567.91ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 565.632ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 557.931ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 574.733ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 133.24ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 130.166ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 117.567ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 106.804ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 143.342ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 90.768ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 152.468ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 138.214ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 123.399ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 97.284ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 754.01ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 727.431ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 749.387ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 735.609ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 778.203ms
#
# Fitting estimator with 372 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 32.499ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 28.29ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.948ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 33.481ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.028ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.842ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.923ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.175ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.231ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.179ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.608ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.74ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.836ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 42.468ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 39.656ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 43.112ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 45.97ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 41.694ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.004ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.501ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 40.876ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 41.339ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 40.357ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 23.667ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 22.472ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 25.053ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 23.579ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 22.712ms
#
# Fitting estimator with 372 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 194.38ms
#
# Fitting estimator with 322 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 120.234ms
#
# Fitting estimator with 272 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 128.266ms
#
# Fitting estimator with 222 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 121.09ms
#
# Fitting estimator with 172 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 110.549ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 84.193ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 105.877ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 98.658ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 104.777ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 101.91ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 101.632ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 95.238ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 76.99ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 62.933ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 57.066ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 73.348ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 91.809ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 159.991ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 93.211ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 93.635ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 95.172ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 117.17ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 92.182ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 101.815ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 112.289ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 100.234ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 93.829ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 91.578ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 79.308ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 81.184ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 69.292ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 82.599ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fe5d264da20>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 370 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 422.339ms
#
# Fitting estimator with 320 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 54.761ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 804.613ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 904.755ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 473.448ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 241.745ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 355.311ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 169.643ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 204.008ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 167.919ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.254ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.263ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 176.336ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 185.547ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 599.572ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 592.928ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 515.181ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 460.951ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 610.314ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 677.944ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 735.727ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 610.392ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 471.617ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 567.528ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 624.965ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 423.665ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 483.383ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 468.218ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 492.071ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.771ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 972.14ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 134.771ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.174ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 81.384ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 49.777ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.374ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 595.553ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 607.804ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 618.577ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 591.779ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 605.061ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 319.34ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 276.846ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 263.021ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 246.457ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 307.506ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 279.546ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 238.433ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 273.727ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 283.423ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 284.518ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 795.512ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 805.864ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 813.206ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 815.898ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 841.734ms
#
# Fitting estimator with 370 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.391ms
#
# Fitting estimator with 320 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.269ms
#
# Fitting estimator with 270 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 28.052ms
#
# Fitting estimator with 220 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 23.442ms
#
# Fitting estimator with 170 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 16.376ms
#
# Fitting estimator with 120 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.989ms
#
# Fitting estimator with 70 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.798ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.499ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.389ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.872ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.232ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.291ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.103ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.362ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.996ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.648ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.818ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.766ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.142ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.278ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.479ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.721ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.914ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.449ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.822ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.532ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.108ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.745ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.888ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.629ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.211ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.461ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.39ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.734ms
#
# Fitting estimator with 370 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 191.131ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 146.349ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 124.053ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 124.535ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 145.914ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 137.911ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 120.213ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 135.386ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 90.298ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 86.535ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 85.996ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 102.695ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 91.8ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 121.406ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 136.554ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 133.904ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 122.855ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 151.811ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 133.069ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 137.346ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 139.922ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 120.219ms
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 121.615ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 110.511ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 137.358ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# ...
# *** Training of classifier ready. Time elapsed: 19.96ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.723ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 11.962ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.42ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.357ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.241ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 42.881ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.985ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.384ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.487ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.955ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.07ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.428ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 25.847ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.488ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.476ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.653ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.224ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.235ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fe5d1d32080>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 130 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 896.494ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 622.38ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 628.937ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 791.988ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 796.728ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 780.993ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 769.229ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 814.69ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 402.904ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 387.677ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 387.101ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.449ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 409.538ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 843.572ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 812.862ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 818.408ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 791.999ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 840.356ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 864.473ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 797.975ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 829.797ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 806.466ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 822.987ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 584.271ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 551.727ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 561.525ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 551.717ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 570.169ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 663.019ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 642.079ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 650.901ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 664.001ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 648.915ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 670.988ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 658.694ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 416.007ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 400.531ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 414.113ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 406.643ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 435.149ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 712.106ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 715.081ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 719.008ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 698.326ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 714.139ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 707.976ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 755.588ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 713.573ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 746.804ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 740.303ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 528.756ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 526.139ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 511.651ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 536.638ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 527.675ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.412ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.551ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.779ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.132ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.437ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.31ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.304ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.854ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.828ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.978ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.951ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.513ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.248ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.619ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.861ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 13.712ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.863ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.143ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.031ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.657ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.506ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 14.551ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.94ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.756ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.501ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.8ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.016ms
#
# Fitting estimator with 130 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 109.167ms
#
# Fitting estimator with 80 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 27.502ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.601ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.338ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.036ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.94ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.899ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.247ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.67ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.471ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.922ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 38.59ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.695ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.342ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.283ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 25.218ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.632ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.255ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.352ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 29.273ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 20.799ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 40.962ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 24.775ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.577ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.506ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.585ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.317ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.442ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.381ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pipeline.id
# Out:
# 248
