# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.api.training import get_training_results
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader
# Out:
# [2020-05-29 21:21:16,497] INFO in __init__: RobotEHR API

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=17)

# %%
feature_pipeline = FeaturePipeline.load(id=21)

# %%
import morpher.config
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__',
    'any__Procedure__', 
    'any__Drug__', 
    'any__Material__', 
    'any__Encounter__', 
    'any__AlcoholUse__', 
    'any__DrugUse__', 
    'any__TobaccoUse__',
    'min__height__', 
    'min__weight__', 
    'min__vitalsign__', 
    'min__measurement__', 
    'min__labvalue__', 
    'max__height__', 
    'max__weight__', 
    'max__vitalsign__', 
    'max__measurement__', 
    'max__labvalue__'
]

agg_func_regex = ""
for r in regexes:
    agg_func_regex += r + "|"
agg_func_regex = agg_func_regex[:-1]

def prepare_data_function(data, target):
    import morpher
    from morpher.jobs import Impute, Scale
    from sklearn.preprocessing import OneHotEncoder
    from enum import Enum
    
    # remove unused features
    del data['medical_record_number']
    del data['mother_account_number']
    del data['date_of_birth']
    del data['month_of_birth']
    del data['patient_ethnic_group']
    del data['religion']
    del data['address_zip']
    del data['deceased_indicator']
    del data['marital_status_code']
    
    class RaceType(str, Enum):
        AFRICAN = 'African'
        AMERICAN_BLACK = 'Black or African-American'
        AMERICAN_NATIVE = 'Native American'
        ASIAN = 'Asian'
        ASIAN_PACIFIC = 'Asian Pacific'
        ASIAN_INDIAN = 'Asian Indian'
        ASIAN_CHINESE = 'Asian Chinese'
        HISPANIC = 'Hispanic or Latino'
        OTHER = 'Other'
        WHITE = 'White'
    
    RACE_MAPPING = {
        RaceType.AFRICAN: [
            'Cape Verdian',
            'Congolese',
            'Eritrean',
            'Ethiopian',
            'Gabonian',
            'Ghanaian',
            'Guinean',
            'Ivory Coastian',
            'Kenyan',
            'Liberian',
            'Madagascar',
            'Malian',
            'Nigerian',
            'Other: East African',
            'Other: North African',
            'Other: South African',
            'Other: West African',
            'Senegalese',
            'Sierra Leonean',
            'Somalian',
            'Sudanese',
            'Tanzanian',
            'Togolese',
            'Ugandan',
            'Zimbabwean'
        ],
        RaceType.AMERICAN_BLACK: [
            'African American (Black)',
            'African-American',
            'Black Or African-American',
            'Black or African - American',
        ],
        RaceType.AMERICAN_NATIVE: [
            'American (Indian/Alaskan)',
            'Native American'
        ],
        RaceType.ASIAN: [
            'Asian',
            'Bangladeshi',
            'Bhutanese',
            'Burmese',
            'Cambodian',
            'Hmong',
            'Indonesian',
            'Japanese',
            'Korean',
            'Laotian',
            'Malaysian',
            'Maldivian',
            'Nepalese',
            'Okinawan',
            'Pakistani',
            'Singaporean',
            'Taiwanese',
            'Thai',
            'Vietnamese',
            'Yapese'
        ],
        RaceType.ASIAN_PACIFIC: [
            'Asian (Pacific Islander)',
            'Carolinian',
            'Chamorro',
            'Chuukese',
            'Fijian',
            'Filipino',
            'Guamanian',
            'Guamanian Or Chamorro',
            'Guamanian or Chamorro',
            'Iwo Jiman',
            'Kiribati',
            'Kosraean',
            'Mariana Islander',
            'Marshallese',
            'Melanesian',
            'Micronesian',
            'Native Hawaiian',
            'New Hebrides',
            'Other Pacific Islander',
            'Pacific Islander',
            'Palauan',
            'Pohnpeian',
            'Polynesian',
            'Saipanese',
            'Samoan',
            'Papua New Guinean',
            'Tahitian',
            'Tokelauan',
            'Tongan'
        ],
        RaceType.ASIAN_INDIAN: [
            'Asian Indian',
            'Sri Lankan',
            'Sri lankan',
            'West Indian'
        ],
        RaceType.ASIAN_CHINESE: [
            'Chinese',
        ],
        RaceType.HISPANIC: [
            'Barbadian',
            'Dominica Islander',
            'Grenadian',
            'Haitian',
            'Hispanic/Latino',
            'Jamaican',
            'St Vincentian',
            'Trinidadian'
        ],
        RaceType.OTHER: [
            '',
            'Aa',
            'Ab',
            'Af',
            'Ag',
            'Ak',
            'Al',
            'Ap',
            'Ar',
            'Av',
            'Ay',
            'B',
            'B1',
            'B2',
            'B3',
            'B4',
            'B5',
            'B6',
            'B7',
            'B8',
            'B9',
            'Ba',
            'Bb',
            'Bc',
            'Bd',
            'Be',
            'Bf',
            'Bg',
            'Bh',
            'Bj',
            'Bk',
            'Bm',
            'Bn',
            'Bo',
            'Bp',
            'Bq',
            'Br',
            'Bs',
            'Bt',
            'Bu',
            'Bv',
            'Bw',
            'Bx',
            'By',
            'Bz',
            'I',
            'MSDW_NOT APPLICABLE',
            'MSDW_OTHER',
            'MSDW_UNKNOWN',
            'NOT AVAILABLE',
            'Non Hispanic',
            'O',
            'Other',
            'Pk',
            'Pl',
            'Pm',
            'Po',
            'Ps',
            'Pv',
            'U',
            'Unk',
            'Unknown',
            'W'
        ],
        RaceType.WHITE: [
            'Caucasian (White)',
            'White'
        ]
    }
    
    # value mapping
    data['race'] = (
        data.race.map({
            label: cat for cat, labels in RACE_MAPPING.items()
            for label in labels
        }).astype(pd.api.types.CategoricalDtype(RaceType))
    )
    
    # pre-encoding nan handling
    for column in ['gender', 'race']:
        enc = OneHotEncoder(sparse=False)
        transformed_data = enc.fit_transform(data[[column]])
        transformed_columns = pd.DataFrame(
            data=transformed_data, 
            columns=[f'{column}_{c}' for c in enc.categories_[0]]
        )
        data = data.join(transformed_columns)
        del data[column]
        
    label_encoded_data = data.copy()
    
    label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]] = label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]].fillna(False)
    
    scaled_data, _ = Scale().execute(data=label_encoded_data, target=target)
    
    imputed_data, _ = Impute().execute(data=scaled_data, imputation_method=morpher.config.imputers.DEFAULT)
    
    return imputed_data

data_loader = DataLoader(agg_func_regex, prepare_data_function)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [(x / 100) for x in range(5, 100, 5)]
observation_windows_occurring = [[x, -1] for x in range(-361, -1, 30)]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator if x[0] == x[2] and x[1] == x[3]]
targets = ['urinary_tract_infection_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.BORDERLINE, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-4 uti no RFE',
    version='14.1.1',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric_binned",
    bin_size=30,
    rfe__run=False,
    rfe__step_size=50
)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4e9fc20240>
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 636.56ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 24.379ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 322.297ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 547.029ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 672.607ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 697.531ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 369.419ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 643.128ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 218.523ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 947.821ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 833.273ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 500.845ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 688.506ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 382.929ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 136.038ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 307.275ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 346.946ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 555.414ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 940.341ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 414.236ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 630.894ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 685.552ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 598.995ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 672.698ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 585.801ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 674.359ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 680.042ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 881.502ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 745.212ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 749.196ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 798.213ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 61.824ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 820.929ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 68.812ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 942.92ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 871.305ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 87.006ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 147.213ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 76.602ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 250.354ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 97.401ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 513.491ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.021ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 360.722ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 501.188ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 552.571ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 386.948ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 410.867ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 426.406ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 414.811ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 438.336ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 225.417ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 223.267ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 227.452ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 207.054ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 222.949ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 428.48ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 448.12ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 465.721ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 474.544ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 420.169ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 468.274ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 494.169ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.88ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 440.81ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 449.062ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 250.483ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 247.013ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 247.938ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 250.597ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 265.658ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 509.969ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 437.716ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 422.529ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 421.038ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 428.834ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 203.995ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 179.511ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 192.741ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 185.27ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 195.149ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 400.2ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 439.982ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 389.018ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 370.033ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 411.923ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 407.236ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 426.701ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 370.223ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 495.315ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 456.25ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 254.42ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 244.564ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 277.663ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 248.664ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 253.066ms
# Columns (11,18,19,20,24,27,35,64,83,90,92,94,95,96,98,105,112,113,115,118,122,123,130,133,137,138,139,140,141,147,168,169,175,232,241,245,246,285,308,313,314,316,321,325,329,336,348,354,355,356,360,376,391,396,414,418,423,427,429,432,439) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4e9fc04e48>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 940.845ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 527.345ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 126.615ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 999.586ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 888.336ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 660.867ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 844.249ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 225.738ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 921.065ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.55ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 59.985ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 990.967ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.705ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 674.468ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 152.308ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 537.209ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 890.552ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 882.068ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 753.78ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 684.316ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 843.673ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 525.971ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 135.859ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 283.272ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 534.719ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 291.19ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 291.292ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 352.916ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 488.496ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 471.872ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 635.753ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 565.83ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 636.847ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 550.985ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 698.621ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 775.112ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 759.909ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 550.157ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 643.68ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 628.504ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 863.156ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 697.539ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 825.673ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 606.249ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 751.698ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 231.389ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 268.528ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 436.416ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 288.117ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 321.129ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 325.67ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 352.529ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 345.882ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 334.759ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 364.469ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 186.216ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 169.241ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 172.531ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 187.95ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 173.882ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 406.754ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 394.6ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 403.093ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 393.881ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 433.475ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 417.576ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 414.662ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 419.415ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 395.829ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 424.695ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 231.564ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 224.545ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 222.56ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 219.544ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 233.835ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 354.403ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 402.661ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 334.36ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 393.282ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 406.027ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 158.249ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 161.648ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 219.683ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 177.756ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 243.42ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 386.885ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 356.284ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 373.004ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 369.81ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 376.82ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 409.479ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 421.852ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 372.084ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 322.028ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 385.782ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 251.027ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 247.032ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 283.206ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 254.568ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 245.598ms
# Columns (10,17,18,19,23,26,30,34,63,82,89,91,93,94,95,96,103,110,111,112,115,118,119,120,127,130,134,135,136,137,143,163,164,170,226,234,238,239,277,303,304,305,308,310,314,318,325,337,343,344,345,349,365,380,385,406,411,415,417,420,427) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4e9fc201d0>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 985.301ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 986.986ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 515.439ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 803.524ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 675.005ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 154.965ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.186ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 654.481ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 362.449ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 684.713ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 754.072ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 166.745ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 548.486ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 695.173ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 411.348ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 388.379ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 234.158ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 892.22ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 529.421ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 45.271ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 193.548ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 605.112ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 617.219ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 68.208ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.145ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 162.193ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 113.298ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 178.616ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 178.921ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 63.983ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 563.074ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 517.098ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 524.789ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 593.558ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 549.083ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 625.662ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 430.838ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 634.376ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 662.71ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 703.337ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 778.596ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 458.467ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 569.753ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 440.566ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 531.806ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 110.071ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 68.566ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 287.142ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 140.198ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 184.657ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 330.265ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 319.376ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 312.088ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 323.552ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 336.3ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 172.401ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 177.021ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 179.833ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 182.294ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 182.891ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 426.985ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 393.58ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 370.053ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 364.485ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 404.446ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 405.333ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 374.981ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 365.7ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 405.342ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.869ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 223.427ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 229.579ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 224.259ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 221.167ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 224.671ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 322.032ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 299.051ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 276.881ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 371.713ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 292.034ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 155.909ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 193.468ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 155.754ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 186.796ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 164.976ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 349.268ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 381.161ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 380.393ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 302.866ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 334.669ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 315.678ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 326.915ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 340.579ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 359.973ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 302.883ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 245.19ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 222.183ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 250.507ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 271.68ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 250.938ms
# Columns (10,15,17,18,19,23,26,30,34,36,40,43,47,55,60,63,64,88,90,92,93,94,95,98,108,109,110,111,113,115,116,117,120,121,122,123,124,127,131,132,133,134,159,160,166,197,202,203,204,206,207,210,213,214,215,218,221,222,223,224,227,228,233,234,235,237,254,257,265,266,267,269,271,272,273,276,277,280,286,287,288,289,290,298,299,300,301,303,305,307,309,313,314,319,320,328,332,333,338,339,340,359,373,374,398,399,404,408,410,419) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4e9ea06cf8>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 956.769ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 508.162ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 780.708ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 111.899ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 417.635ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 287.402ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 128.886ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 265.693ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 373.391ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 353.488ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 357.256ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 208.77ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 387.425ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 902.424ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 735.825ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 141.078ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 156.712ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 236.233ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 941.118ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 944.664ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 409.147ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 568.869ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 399.037ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 764.74ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 509.834ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 958.383ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 971.13ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 988.419ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 980.397ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 54.825ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 529.826ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 495.517ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 501.944ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 519.883ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 510.052ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 435.907ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 290.009ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 189.477ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 514.254ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 326.317ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 379.618ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 301.11ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 280.204ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 287.606ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 519.496ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 49.968ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.311ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 964.023ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.318ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 81.8ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 325.074ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 326.055ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 299.011ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 311.513ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 320.068ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 161.588ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 162.104ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 164.151ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 156.833ms
#
# ...
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.368ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.642ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 10.338ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 11.713ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 10.285ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 7.948ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 26.555ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.449ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.094ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.635ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.758ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.807ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.497ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.415ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 10.273ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 10.179ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.664ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.608ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.189ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 34.121ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.123ms
#
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4e9e4f4cf8>
# Fetching data for Patient (...)
# *** Training of model 'GradientBoostingClassifier' started.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of classifier ready. Time elapsed: 257.164ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 246.782ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 253.75ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 249.932ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 275.956ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 159.327ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 156.164ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 153.734ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 140.711ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 145.711ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 257.92ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 261.804ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 251.92ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 263.388ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 260.591ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 269.42ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 265.018ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 269.278ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 244.952ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 232.614ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 216.821ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 217.389ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 215.427ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 209.067ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 211.173ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 472.313ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 475.32ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 449.353ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 472.115ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 490.383ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 337.565ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 294.467ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 325.6ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 343.695ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 347.068ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.155ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 455.491ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 453.067ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 460.953ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 465.491ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 460.025ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 446.686ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 455.337ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.33ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 426.409ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 374.224ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 377.706ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 385.5ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 379.106ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.631ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.363ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.989ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.762ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.868ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.405ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.09ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.991ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.019ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.115ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.696ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.539ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.628ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.377ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.457ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.659ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.596ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.766ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.384ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.512ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.82ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.818ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.609ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.875ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.223ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.688ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.937ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.797ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.891ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.819ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.471ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 11.949ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 9.277ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 7.198ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.16ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 8.564ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.013ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.818ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.502ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 10.985ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.499ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.715ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.212ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.476ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.235ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.702ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.12ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.132ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.308ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 9.72ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 11.902ms
#
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4e9e814cf8>
# Fetching data for Patient (...)
# *** Training of model 'GradientBoostingClassifier' started.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of classifier ready. Time elapsed: 238.167ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 263.77ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 237.127ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 242.961ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 243.641ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 166.915ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 153.519ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 144.456ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 153.944ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 165.025ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 258.274ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pipeline.id
# Out:
# 244
