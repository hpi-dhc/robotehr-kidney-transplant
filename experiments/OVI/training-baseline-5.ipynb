# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.api.training import get_training_results
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader
# Out:
# [2020-05-21 10:24:32,715] INFO in __init__: RobotEHR API

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=18)

# %%
feature_pipeline = FeaturePipeline.load(id=22)

# %%
import morpher.config
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__',
    'any__Procedure__', 
    'any__Drug__', 
    'any__Material__', 
    'any__Encounter__', 
    'any__AlcoholUse__', 
    'any__DrugUse__', 
    'any__TobaccoUse__',
]

agg_func_regex = ""
for r in regexes:
    agg_func_regex += r + "|"
agg_func_regex = agg_func_regex[:-1]

def prepare_data_function(data, target):
    import morpher
    from morpher.jobs import Impute, Scale
    from sklearn.preprocessing import OneHotEncoder
    from enum import Enum
    
    # remove unused features
    del data['medical_record_number']
    del data['mother_account_number']
    del data['date_of_birth']
    del data['month_of_birth']
    del data['patient_ethnic_group']
    del data['religion']
    del data['address_zip']
    del data['deceased_indicator']
    del data['marital_status_code']
    
    class RaceType(str, Enum):
        AFRICAN = 'African'
        AMERICAN_BLACK = 'Black or African-American'
        AMERICAN_NATIVE = 'Native American'
        ASIAN = 'Asian'
        ASIAN_PACIFIC = 'Asian Pacific'
        ASIAN_INDIAN = 'Asian Indian'
        ASIAN_CHINESE = 'Asian Chinese'
        HISPANIC = 'Hispanic or Latino'
        OTHER = 'Other'
        WHITE = 'White'
    
    RACE_MAPPING = {
        RaceType.AFRICAN: [
            'Cape Verdian',
            'Congolese',
            'Eritrean',
            'Ethiopian',
            'Gabonian',
            'Ghanaian',
            'Guinean',
            'Ivory Coastian',
            'Kenyan',
            'Liberian',
            'Madagascar',
            'Malian',
            'Nigerian',
            'Other: East African',
            'Other: North African',
            'Other: South African',
            'Other: West African',
            'Senegalese',
            'Sierra Leonean',
            'Somalian',
            'Sudanese',
            'Tanzanian',
            'Togolese',
            'Ugandan',
            'Zimbabwean'
        ],
        RaceType.AMERICAN_BLACK: [
            'African American (Black)',
            'African-American',
            'Black Or African-American',
            'Black or African - American',
        ],
        RaceType.AMERICAN_NATIVE: [
            'American (Indian/Alaskan)',
            'Native American'
        ],
        RaceType.ASIAN: [
            'Asian',
            'Bangladeshi',
            'Bhutanese',
            'Burmese',
            'Cambodian',
            'Hmong',
            'Indonesian',
            'Japanese',
            'Korean',
            'Laotian',
            'Malaysian',
            'Maldivian',
            'Nepalese',
            'Okinawan',
            'Pakistani',
            'Singaporean',
            'Taiwanese',
            'Thai',
            'Vietnamese',
            'Yapese'
        ],
        RaceType.ASIAN_PACIFIC: [
            'Asian (Pacific Islander)',
            'Carolinian',
            'Chamorro',
            'Chuukese',
            'Fijian',
            'Filipino',
            'Guamanian',
            'Guamanian Or Chamorro',
            'Guamanian or Chamorro',
            'Iwo Jiman',
            'Kiribati',
            'Kosraean',
            'Mariana Islander',
            'Marshallese',
            'Melanesian',
            'Micronesian',
            'Native Hawaiian',
            'New Hebrides',
            'Other Pacific Islander',
            'Pacific Islander',
            'Palauan',
            'Pohnpeian',
            'Polynesian',
            'Saipanese',
            'Samoan',
            'Papua New Guinean',
            'Tahitian',
            'Tokelauan',
            'Tongan'
        ],
        RaceType.ASIAN_INDIAN: [
            'Asian Indian',
            'Sri Lankan',
            'Sri lankan',
            'West Indian'
        ],
        RaceType.ASIAN_CHINESE: [
            'Chinese',
        ],
        RaceType.HISPANIC: [
            'Barbadian',
            'Dominica Islander',
            'Grenadian',
            'Haitian',
            'Hispanic/Latino',
            'Jamaican',
            'St Vincentian',
            'Trinidadian'
        ],
        RaceType.OTHER: [
            '',
            'Aa',
            'Ab',
            'Af',
            'Ag',
            'Ak',
            'Al',
            'Ap',
            'Ar',
            'Av',
            'Ay',
            'B',
            'B1',
            'B2',
            'B3',
            'B4',
            'B5',
            'B6',
            'B7',
            'B8',
            'B9',
            'Ba',
            'Bb',
            'Bc',
            'Bd',
            'Be',
            'Bf',
            'Bg',
            'Bh',
            'Bj',
            'Bk',
            'Bm',
            'Bn',
            'Bo',
            'Bp',
            'Bq',
            'Br',
            'Bs',
            'Bt',
            'Bu',
            'Bv',
            'Bw',
            'Bx',
            'By',
            'Bz',
            'I',
            'MSDW_NOT APPLICABLE',
            'MSDW_OTHER',
            'MSDW_UNKNOWN',
            'NOT AVAILABLE',
            'Non Hispanic',
            'O',
            'Other',
            'Pk',
            'Pl',
            'Pm',
            'Po',
            'Ps',
            'Pv',
            'U',
            'Unk',
            'Unknown',
            'W'
        ],
        RaceType.WHITE: [
            'Caucasian (White)',
            'White'
        ]
    }
    
    # value mapping
    data['race'] = (
        data.race.map({
            label: cat for cat, labels in RACE_MAPPING.items()
            for label in labels
        }).astype(pd.api.types.CategoricalDtype(RaceType))
    )
    
    # pre-encoding nan handling
    for column in ['gender', 'race']:
        enc = OneHotEncoder(sparse=False)
        transformed_data = enc.fit_transform(data[[column]])
        transformed_columns = pd.DataFrame(
            data=transformed_data, 
            columns=[f'{column}_{c}' for c in enc.categories_[0]]
        )
        data = data.join(transformed_columns)
        del data[column]
        
    label_encoded_data = data.copy()
    
    label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]] = label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]].fillna(False)
    
    scaled_data, _ = Scale().execute(data=label_encoded_data, target=target)
    
    imputed_data, _ = Impute().execute(data=scaled_data, imputation_method=morpher.config.imputers.DEFAULT)
    
    return imputed_data

data_loader = DataLoader(agg_func_regex, prepare_data_function)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [(x / 100) for x in range(5, 100, 5)]
observation_windows_occurring = [[x, -1] for x in range(-361, -1, 30)]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator if x[0] == x[2] and x[1] == x[3]]
targets = ['other_viral_infection_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.BORDERLINE, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-5 ovi time series',
    version='35.1.0',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric_time_series",
    rfe__run=True,
    rfe__step_size=50
)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f06de2ba0b8>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 932 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 965.829ms
#
# Fitting estimator with 882 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 840.806ms
#
# Fitting estimator with 832 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 865.979ms
#
# Fitting estimator with 782 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 811.828ms
#
# Fitting estimator with 732 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 618.471ms
#
# Fitting estimator with 682 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 260.875ms
#
# Fitting estimator with 632 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 607.577ms
#
# Fitting estimator with 582 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 360.167ms
#
# Fitting estimator with 532 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 800.78ms
#
# Fitting estimator with 482 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 267.864ms
#
# Fitting estimator with 432 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 843.208ms
#
# Fitting estimator with 382 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 412.868ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 118.991ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 217.262ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 398.227ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 221.465ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 516.0ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 731.131ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 728.266ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 815.651ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 545.983ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 623.385ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 531.961ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 718.573ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 876.438ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 856.17ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 283.617ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 627.152ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 373.578ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 228.836ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 871.224ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 262.455ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 340.422ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 44.36ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 525.176ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 712.842ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 387.272ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 405.31ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 379.574ms
#
# Fitting estimator with 932 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 151.826ms
#
# Fitting estimator with 882 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 107.299ms
#
# Fitting estimator with 832 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 526.619ms
#
# Fitting estimator with 782 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 393.025ms
#
# Fitting estimator with 732 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 835.232ms
#
# Fitting estimator with 682 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 724.727ms
#
# Fitting estimator with 632 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 998.223ms
#
# Fitting estimator with 582 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 728.204ms
#
# Fitting estimator with 532 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 134.762ms
#
# Fitting estimator with 482 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 83.027ms
#
# Fitting estimator with 432 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 749.075ms
#
# Fitting estimator with 382 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 712.989ms
#
# Fitting estimator with 332 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 470.545ms
#
# Fitting estimator with 282 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 730.459ms
#
# Fitting estimator with 232 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 366.963ms
#
# Fitting estimator with 182 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 252.308ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 171.601ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 343.598ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 221.841ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.189ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 991.436ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 809.738ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 567.807ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 647.997ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 622.958ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 860.657ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 672.486ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.013ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 962.736ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 984.091ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 811.85ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 634.44ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 641.279ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 886.234ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 635.207ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.881ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 789.583ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 646.635ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 135.26ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 532.857ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 963.583ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 950.861ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 130.747ms
#
# Fitting estimator with 932 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 232.933ms
#
# Fitting estimator with 882 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 156.313ms
#
# Fitting estimator with 832 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 134.471ms
#
# Fitting estimator with 782 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 165.772ms
#
# Fitting estimator with 732 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 147.523ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 118.782ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.123ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 184.957ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 185.899ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 194.873ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 170.769ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 201.216ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 59.499ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 47.655ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 74.362ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 61.955ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.462ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 117.088ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 120.76ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 283.222ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 255.639ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 117.633ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 124.007ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 125.928ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 263.249ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 264.357ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 283.654ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 106.698ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.696ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 129.202ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 110.289ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 94.306ms
#
# Fitting estimator with 932 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 581.741ms
#
# Fitting estimator with 882 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 82.725ms
#
# Fitting estimator with 832 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 832.205ms
#
# Fitting estimator with 782 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 94.839ms
#
# Fitting estimator with 732 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 886.503ms
#
# Fitting estimator with 682 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 666.091ms
#
# Fitting estimator with 632 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 750.724ms
#
# Fitting estimator with 582 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 941.532ms
#
# Fitting estimator with 532 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 868.127ms
#
# Fitting estimator with 482 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 618.814ms
#
# Fitting estimator with 432 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 164.937ms
#
# Fitting estimator with 382 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 193.971ms
#
# Fitting estimator with 332 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 279.607ms
#
# Fitting estimator with 282 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 844.584ms
#
# Fitting estimator with 232 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 837.57ms
#
# Fitting estimator with 182 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 849.645ms
#
# Fitting estimator with 132 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 654.738ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 872.872ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 315.138ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 901.453ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 811.408ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 214.414ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 66.111ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 351.927ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 370.518ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 743.73ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 629.539ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 943.484ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 491.754ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.115ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 601.86ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 883.513ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 628.863ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 694.1ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 551.825ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 497.394ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 243.418ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 829.396ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 178.592ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 875.321ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 413.202ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 478.555ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 583.668ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 513.757ms
# Columns (11,18,19,20,24,27,35,64,83,90,92,94,95,96,98,105,112,113,115,118,122,123,130,133,137,138,139,140,141,147,168,169,175,232,241,245,246,285,308,313,314,316,321,325,329,336,348,354,355,356,360,376,391,396,414,418,423,427,429,432,439) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f06de1df710>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 912 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 422.859ms
#
# Fitting estimator with 862 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 681.967ms
#
# Fitting estimator with 812 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 914.869ms
#
# Fitting estimator with 762 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 923.381ms
#
# Fitting estimator with 712 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 562.464ms
#
# Fitting estimator with 662 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 125.868ms
#
# Fitting estimator with 612 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 129.731ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 534.795ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 906.191ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 201.395ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 243.087ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 493.725ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 218.838ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 492.78ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 984.435ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 930.373ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 971.902ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 918.978ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 45.539ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 562.907ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 581.242ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 565.044ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 381.365ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 536.935ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 444.836ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 561.434ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 361.288ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 375.942ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 469.235ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 174.011ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 261.896ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 261.734ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 265.747ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 178.198ms
#
# Fitting estimator with 912 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 430.299ms
#
# Fitting estimator with 862 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 420.968ms
#
# Fitting estimator with 812 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 390.795ms
#
# Fitting estimator with 762 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 323.732ms
#
# Fitting estimator with 712 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 352.045ms
#
# Fitting estimator with 662 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 343.896ms
#
# Fitting estimator with 612 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 319.723ms
#
# Fitting estimator with 562 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 267.171ms
#
# Fitting estimator with 512 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 311.557ms
#
# Fitting estimator with 462 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 243.373ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 232.313ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 241.26ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 606.609ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 636.228ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 589.939ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 558.567ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 579.194ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 721.359ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 700.707ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 698.326ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 714.235ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 665.748ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 837.376ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 814.712ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 775.045ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 748.102ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 835.687ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 877.965ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 819.008ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 799.071ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 806.378ms
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 825.545ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 989.581ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.4ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 972.456ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.578ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 30.254ms
#
# Fitting estimator with 912 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 77.204ms
#
# Fitting estimator with 862 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 63.722ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 60.531ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 63.881ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 85.843ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 88.662ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 82.852ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 82.706ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 84.929ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.283ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.285ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.363ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.402ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 32.223ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 112.474ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 119.106ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 114.546ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 113.694ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 125.953ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 117.798ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.735ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 116.237ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 127.462ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 128.253ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 56.111ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 55.817ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 53.822ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 55.928ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 53.955ms
#
# Fitting estimator with 912 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 259.788ms
#
# Fitting estimator with 862 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 172.672ms
#
# Fitting estimator with 812 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 370.763ms
#
# Fitting estimator with 762 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 191.233ms
#
# Fitting estimator with 712 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 160.021ms
#
# Fitting estimator with 662 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 163.408ms
#
# Fitting estimator with 612 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 251.186ms
#
# Fitting estimator with 562 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 250.185ms
#
# Fitting estimator with 512 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 176.32ms
#
# Fitting estimator with 462 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 145.398ms
#
# Fitting estimator with 412 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 137.623ms
#
# Fitting estimator with 362 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 145.57ms
#
# Fitting estimator with 312 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 157.839ms
#
# Fitting estimator with 262 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 134.2ms
#
# Fitting estimator with 212 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 124.047ms
#
# Fitting estimator with 162 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 226.329ms
#
# Fitting estimator with 112 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 106.988ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 49.202ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 56.205ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 67.136ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 73.034ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 99.478ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 69.723ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 63.566ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 50.875ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 37.125ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 37.988ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 39.442ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 37.348ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 95.012ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 89.841ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 74.066ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 91.63ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 68.562ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 159.211ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 164.686ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 331.92ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 233.397ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 207.339ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 118.087ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 134.034ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 115.851ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 115.85ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 107.685ms
# Columns (10,17,18,19,23,26,30,34,63,82,89,91,93,94,95,96,103,110,111,112,115,118,119,120,127,130,134,135,136,137,143,163,164,170,226,234,238,239,277,303,304,305,308,310,314,318,325,337,343,344,345,349,365,380,385,406,411,415,417,420,427) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f06ddcb75f8>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 890 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 976.088ms
#
# Fitting estimator with 840 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 540.941ms
#
# Fitting estimator with 790 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 555.289ms
#
# Fitting estimator with 740 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 942.787ms
#
# Fitting estimator with 690 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 601.449ms
#
# Fitting estimator with 640 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 429.385ms
#
# Fitting estimator with 590 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 962.551ms
#
# Fitting estimator with 540 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 688.476ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 474.453ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 377.049ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 557.507ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 586.728ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 80.804ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 987.427ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 652.702ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 783.422ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 738.137ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 825.076ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 724.224ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 784.071ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 71.078ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 255.029ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 405.25ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 927.776ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 285.8ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 371.517ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 489.006ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 353.103ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 421.181ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 269.259ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 690.301ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 760.227ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 753.809ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 827.273ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 847.467ms
#
# Fitting estimator with 890 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 421.371ms
#
# Fitting estimator with 840 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 414.865ms
#
# Fitting estimator with 790 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 474.75ms
#
# Fitting estimator with 740 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 413.428ms
#
# Fitting estimator with 690 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 368.254ms
#
# Fitting estimator with 640 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 333.48ms
#
# Fitting estimator with 590 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 282.966ms
#
# Fitting estimator with 540 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 306.453ms
#
# Fitting estimator with 490 features.
# *** Training of model 'RandomForestClassifier' started.
# ...
# *** Training of classifier ready. Time elapsed: 19.728ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 641.47ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 720.998ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 221.44ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 589.528ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 684.681ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 31.735ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 86.201ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 338.335ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 121.096ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 808.307ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 266.022ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 850.844ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 910.172ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 874.698ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 523.129ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 740.31ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 373.329ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 991.145ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 484.44ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 866.876ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 998.822ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 272.669ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 724.683ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 46.7ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 707.324ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 715.833ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 639.577ms
#
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f06dc339470>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 627.307ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 539.951ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 831.083ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 95.204ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 97.996ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 899.084ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 574.361ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 316.678ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 304.909ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 303.233ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 301.107ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 323.394ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 96.152ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 140.577ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 214.317ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 705.911ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 713.147ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 309.284ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 350.225ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 124.803ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.315ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 768.602ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 969.088ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 202.129ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 622.075ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 170.175ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 765.295ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 380.039ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 136.512ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 704.237ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 346.333ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.751ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 68.618ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 33.374ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 624.482ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 228.021ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 207.305ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 229.677ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 190.819ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 70.597ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 27.624ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 999.341ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 986.692ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.93ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 994.09ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 22.985ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 363.662ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 889.04ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 868.046ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 537.89ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 529.318ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 549.686ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 255.249ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 818.96ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.614ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.048ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.944ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.146ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.311ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.302ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.849ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.12ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.325ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.923ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.199ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.611ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.137ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.112ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.296ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.975ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.217ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.766ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.147ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.409ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.107ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.143ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 6.58ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.809ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.043ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.319ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.804ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 608.33ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 832.328ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 687.327ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 753.867ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 351.629ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 758.639ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 989.542ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.399ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 482.988ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 649.298ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 852.57ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 291.25ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.77ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 831.536ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 408.696ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 710.671ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 456.281ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 739.747ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 422.999ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 329.008ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 567.983ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 788.877ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 670.806ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 986.073ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 296.9ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 761.167ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 641.969ms
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pipeline.id
# Out:
# 200

# %% [markdown]
# # Results

# %%
from robotehr.api.training import get_training_results
get_training_results(200, sort_by='auc_roc_mean', metrics=['auc_roc_mean', 'precision_mean', 'auc_prc_mean', 'recall_mean'], n_rows=10000, response_type="pandas")
# Out:
#                          algorithm  auc_prc_mean  auc_roc_mean  \
# 0               LogisticRegression      0.696343      0.814489
# 1               LogisticRegression      0.693578      0.810490
# 2               LogisticRegression      0.698796      0.810283
# 3               LogisticRegression      0.691024      0.807448
# 4               LogisticRegression      0.700876      0.805049
# 5               LogisticRegression      0.681019      0.804877
# 6               LogisticRegression      0.696564      0.801032
# 7               LogisticRegression      0.692505      0.798727
# 8               LogisticRegression      0.696604      0.798699
# 9               LogisticRegression      0.690991      0.798414
# 10    GradientBoostingDecisionTree      0.680560      0.792827
# 11              LogisticRegression      0.681132      0.791862
# 12              LogisticRegression      0.679308      0.791080
# 13              LogisticRegression      0.675304      0.786948
# 14    GradientBoostingDecisionTree      0.680397      0.786117
# 15              LogisticRegression      0.674936      0.785329
# 16              LogisticRegression      0.666382      0.785322
# 17              LogisticRegression      0.680885      0.785162
# 18    GradientBoostingDecisionTree      0.669952      0.784689
# 19              LogisticRegression      0.680995      0.784586
# 20              LogisticRegression      0.670601      0.784482
# 21                    RandomForest      0.670948      0.784001
# 22                    RandomForest      0.665632      0.783708
# 23                    RandomForest      0.671879      0.780810
# 24    GradientBoostingDecisionTree      0.661042      0.780263
# 25    GradientBoostingDecisionTree      0.666879      0.778524
# 26              LogisticRegression      0.675945      0.777996
# 27    GradientBoostingDecisionTree      0.658703      0.777692
# 28                    RandomForest      0.649143      0.777020
# 29              LogisticRegression      0.674469      0.776833
# ...                            ...           ...           ...
# 4530                  DecisionTree      0.298972      0.575025
# 4531                  DecisionTree      0.301187      0.575014
# 4532  GradientBoostingDecisionTree      0.332731      0.574607
# 4533                  RandomForest      0.343403      0.574546
# 4534                  DecisionTree      0.354489      0.574431
# 4535  GradientBoostingDecisionTree      0.341549      0.574409
# 4536  GradientBoostingDecisionTree      0.329221      0.574378
# 4537  GradientBoostingDecisionTree      0.340796      0.574213
# 4538                  DecisionTree      0.307136      0.573923
# 4539  GradientBoostingDecisionTree      0.331250      0.573866
# 4540                  DecisionTree      0.300619      0.573738
# 4541  GradientBoostingDecisionTree      0.335654      0.573520
# 4542  GradientBoostingDecisionTree      0.329172      0.573506
# 4543  GradientBoostingDecisionTree      0.329079      0.573436
# 4544  GradientBoostingDecisionTree      0.332196      0.572798
# 4545                  DecisionTree      0.303603      0.572788
# 4546                  DecisionTree      0.340678      0.572507
# 4547  GradientBoostingDecisionTree      0.340958      0.571613
# 4548  GradientBoostingDecisionTree      0.328595      0.570951
# 4549  GradientBoostingDecisionTree      0.316279      0.570682
# 4550                  DecisionTree      0.295821      0.569778
# 4551                  DecisionTree      0.352488      0.568209
# 4552                  DecisionTree      0.313797      0.567201
# 4553                  DecisionTree      0.310307      0.566457
# 4554  GradientBoostingDecisionTree      0.319793      0.565513
# 4555  GradientBoostingDecisionTree      0.328522      0.563754
# 4556  GradientBoostingDecisionTree      0.321395      0.562784
# 4557  GradientBoostingDecisionTree      0.336316      0.562537
# 4558                  DecisionTree      0.356272      0.561610
# 4559                  DecisionTree      0.309803      0.552172
#
#       precision_mean  recall_mean             sampler  \
# 0           0.577878     0.664913           NoSampler
# 1           0.575911     0.654657   RandomOverSampler
# 2           0.555341     0.670144     BorderlineSMOTE
# 3           0.571774     0.651194               SMOTE
# 4           0.566011     0.649573           NoSampler
# 5           0.547318     0.694253  RandomUnderSampler
# 6           0.556133     0.635824   RandomOverSampler
# 7           0.527659     0.656469     BorderlineSMOTE
# 8           0.548177     0.634100               SMOTE
# 9           0.537040     0.642720  RandomUnderSampler
# 10          0.734135     0.415768           NoSampler
# 11          0.565973     0.640849           NoSampler
# 12          0.559195     0.637371   RandomOverSampler
# 13          0.546580     0.630563               SMOTE
# 14          0.598138     0.565281   RandomOverSampler
# 15          0.511852     0.668302  RandomUnderSampler
# 16          0.541188     0.651238  RandomUnderSampler
# 17          0.553720     0.611656           NoSampler
# 18          0.682380     0.451798     BorderlineSMOTE
# 19          0.576743     0.616844   RandomOverSampler
# 20          0.516527     0.659711     BorderlineSMOTE
# 21          0.658018     0.467286           NoSampler
# 22          0.685925     0.455320               SMOTE
# 23          0.646021     0.506852   RandomOverSampler
# 24          0.690563     0.429502               SMOTE
# 25          0.699155     0.444901               SMOTE
# 26          0.527771     0.616799               SMOTE
# 27          0.676051     0.434704     BorderlineSMOTE
# 28          0.607851     0.501650   RandomOverSampler
# 29          0.473528     0.709579     BorderlineSMOTE
# ...              ...          ...                 ...
# 4530        0.348584     0.566976  RandomUnderSampler
# 4531        0.351810     0.551562  RandomUnderSampler
# 4532        0.324036     0.566829  RandomUnderSampler
# 4533        0.338961     0.484380   RandomOverSampler
# 4534        0.357310     0.450103               SMOTE
# 4535        0.326350     0.561760  RandomUnderSampler
# 4536        0.329322     0.568759  RandomUnderSampler
# 4537        0.325709     0.561760  RandomUnderSampler
# 4538        0.354480     0.567109  RandomUnderSampler
# 4539        0.343139     0.585838  RandomUnderSampler
# 4540        0.340418     0.604657  RandomUnderSampler
# 4541        0.334301     0.585735  RandomUnderSampler
# 4542        0.335642     0.566814  RandomUnderSampler
# 4543        0.327126     0.563322  RandomUnderSampler
# 4544        0.330227     0.584041  RandomUnderSampler
# 4545        0.346387     0.578927  RandomUnderSampler
# 4546        0.325987     0.460139               SMOTE
# 4547        0.325797     0.568597  RandomUnderSampler
# 4548        0.323455     0.571927  RandomUnderSampler
# 4549        0.333965     0.584011  RandomUnderSampler
# 4550        0.322060     0.601429     BorderlineSMOTE
# 4551        0.363217     0.438182     BorderlineSMOTE
# 4552        0.340760     0.524020  RandomUnderSampler
# 4553        0.347935     0.522370  RandomUnderSampler
# 4554        0.325690     0.578927  RandomUnderSampler
# 4555        0.324100     0.558341  RandomUnderSampler
# 4556        0.322670     0.558282  RandomUnderSampler
# 4557        0.324267     0.556617  RandomUnderSampler
# 4558        0.328968     0.471294     BorderlineSMOTE
# 4559        0.328586     0.535927  RandomUnderSampler
#
#                                                                target  \
# 0     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 1     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 2     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 3     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 5     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 6     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 7     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 8     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 9     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 10    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 11    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 12    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 13    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 14    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 15    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 16    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 17    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 18    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 19    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 20    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 21    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 22    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 23    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 24    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 25    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 26    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 27    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 28    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 29    other_viral_infection_onset_from_0_days_after_to_365_days_after
# ...                                                               ...
# 4530  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4531  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4532  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4533  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4534  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4535  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4536  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4537  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4538  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4539  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4540  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4541  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4542  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4543  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4544  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4545  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4546  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4547  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4548  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4549  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4550  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4551  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4552  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4553  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4554  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4555  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4556  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4557  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4558  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4559  other_viral_infection_onset_from_0_days_after_to_365_days_after
#
#       threshold_numeric  threshold_occurring  window_start_numeric  \
# 0                  0.05                 0.05                  -271
# 1                  0.05                 0.05                  -271
# 2                  0.05                 0.05                  -271
# 3                  0.05                 0.05                  -271
# 4                  0.05                 0.05                  -361
# 5                  0.05                 0.05                  -271
# 6                  0.05                 0.05                  -361
# 7                  0.05                 0.05                  -361
# 8                  0.05                 0.05                  -361
# 9                  0.05                 0.05                  -361
# 10                 0.05                 0.05                  -361
# 11                 0.05                 0.05                  -241
# 12                 0.05                 0.05                  -241
# 13                 0.05                 0.05                  -241
# 14                 0.05                 0.05                  -361
# 15                 0.05                 0.05                  -331
# 16                 0.05                 0.05                  -241
# 17                 0.05                 0.05                  -331
# 18                 0.05                 0.05                  -361
# 19                 0.05                 0.05                  -331
# 20                 0.05                 0.05                  -241
# 21                 0.05                 0.05                  -361
# 22                 0.05                 0.05                  -361
# 23                 0.05                 0.05                  -361
# 24                 0.05                 0.05                  -331
# 25                 0.05                 0.05                  -301
# 26                 0.05                 0.05                  -331
# 27                 0.05                 0.05                  -331
# 28                 0.05                 0.05                  -241
# 29                 0.05                 0.05                  -331
# ...                 ...                  ...                   ...
# 4530               0.85                 0.85                  -361
# 4531               0.95                 0.95                  -211
# 4532               0.90                 0.90                  -361
# 4533               0.70                 0.70                  -121
# 4534               0.55                 0.55                  -121
# 4535               0.80                 0.80                  -211
# 4536               0.80                 0.80                  -181
# 4537               0.95                 0.95                  -181
# 4538               0.70                 0.70                  -151
# 4539               0.85                 0.85                   -31
# 4540               0.90                 0.90                   -31
# 4541               0.70                 0.70                   -31
# 4542               0.75                 0.75                   -31
# 4543               0.75                 0.75                  -211
# 4544               0.80                 0.80                   -91
# 4545               0.75                 0.75                  -271
# 4546               0.40                 0.40                  -151
# 4547               0.90                 0.90                   -31
# 4548               0.95                 0.95                  -121
# 4549               0.90                 0.90                  -271
# 4550               0.85                 0.85                  -181
# 4551               0.50                 0.50                  -331
# 4552               0.85                 0.85                  -151
# 4553               0.95                 0.95                  -361
# 4554               0.90                 0.90                  -121
# 4555               0.75                 0.75                  -151
# 4556               0.70                 0.70                   -91
# 4557               0.80                 0.80                   -31
# 4558               0.45                 0.45                  -241
# 4559               0.85                 0.85                   -91
#
#       window_start_occurring
# 0                       -271
# 1                       -271
# 2                       -271
# 3                       -271
# 4                       -361
# 5                       -271
# 6                       -361
# 7                       -361
# 8                       -361
# 9                       -361
# 10                      -361
# 11                      -241
# 12                      -241
# 13                      -241
# 14                      -361
# 15                      -331
# 16                      -241
# 17                      -331
# 18                      -361
# 19                      -331
# 20                      -241
# 21                      -361
# 22                      -361
# 23                      -361
# 24                      -331
# 25                      -301
# 26                      -331
# 27                      -331
# 28                      -241
# 29                      -331
# ...                      ...
# 4530                    -361
# 4531                    -211
# 4532                    -361
# 4533                    -121
# 4534                    -121
# 4535                    -211
# 4536                    -181
# 4537                    -181
# 4538                    -151
# 4539                     -31
# 4540                     -31
# 4541                     -31
# 4542                     -31
# 4543                    -211
# 4544                     -91
# 4545                    -271
# 4546                    -151
# 4547                     -31
# 4548                    -121
# 4549                    -271
# 4550                    -181
# 4551                    -331
# 4552                    -151
# 4553                    -361
# 4554                    -121
# 4555                    -151
# 4556                     -91
# 4557                     -31
# 4558                    -241
# 4559                     -91
#
# [4560 rows x 11 columns]
