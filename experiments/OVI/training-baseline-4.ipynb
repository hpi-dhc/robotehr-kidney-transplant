# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.api.training import get_training_results
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader
# Out:
# [2020-05-19 16:56:48,340] INFO in __init__: RobotEHR API

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=18)

# %%
feature_pipeline = FeaturePipeline.load(id=21)

# %%
import morpher.config
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__',
    'any__Procedure__', 
    'any__Drug__', 
    'any__Material__', 
    'any__Encounter__', 
    'any__AlcoholUse__', 
    'any__DrugUse__', 
    'any__TobaccoUse__',
    'min__height__', 
    'min__weight__', 
    'min__vitalsign__', 
    'min__measurement__', 
    'min__labvalue__', 
    'max__height__', 
    'max__weight__', 
    'max__vitalsign__', 
    'max__measurement__', 
    'max__labvalue__'
]

agg_func_regex = ""
for r in regexes:
    agg_func_regex += r + "|"
agg_func_regex = agg_func_regex[:-1]

def prepare_data_function(data, target):
    import morpher
    from morpher.jobs import Impute, Scale
    from sklearn.preprocessing import OneHotEncoder
    from enum import Enum
    
    # remove unused features
    del data['medical_record_number']
    del data['mother_account_number']
    del data['date_of_birth']
    del data['month_of_birth']
    del data['patient_ethnic_group']
    del data['religion']
    del data['address_zip']
    del data['deceased_indicator']
    del data['marital_status_code']
    
    class RaceType(str, Enum):
        AFRICAN = 'African'
        AMERICAN_BLACK = 'Black or African-American'
        AMERICAN_NATIVE = 'Native American'
        ASIAN = 'Asian'
        ASIAN_PACIFIC = 'Asian Pacific'
        ASIAN_INDIAN = 'Asian Indian'
        ASIAN_CHINESE = 'Asian Chinese'
        HISPANIC = 'Hispanic or Latino'
        OTHER = 'Other'
        WHITE = 'White'
    
    RACE_MAPPING = {
        RaceType.AFRICAN: [
            'Cape Verdian',
            'Congolese',
            'Eritrean',
            'Ethiopian',
            'Gabonian',
            'Ghanaian',
            'Guinean',
            'Ivory Coastian',
            'Kenyan',
            'Liberian',
            'Madagascar',
            'Malian',
            'Nigerian',
            'Other: East African',
            'Other: North African',
            'Other: South African',
            'Other: West African',
            'Senegalese',
            'Sierra Leonean',
            'Somalian',
            'Sudanese',
            'Tanzanian',
            'Togolese',
            'Ugandan',
            'Zimbabwean'
        ],
        RaceType.AMERICAN_BLACK: [
            'African American (Black)',
            'African-American',
            'Black Or African-American',
            'Black or African - American',
        ],
        RaceType.AMERICAN_NATIVE: [
            'American (Indian/Alaskan)',
            'Native American'
        ],
        RaceType.ASIAN: [
            'Asian',
            'Bangladeshi',
            'Bhutanese',
            'Burmese',
            'Cambodian',
            'Hmong',
            'Indonesian',
            'Japanese',
            'Korean',
            'Laotian',
            'Malaysian',
            'Maldivian',
            'Nepalese',
            'Okinawan',
            'Pakistani',
            'Singaporean',
            'Taiwanese',
            'Thai',
            'Vietnamese',
            'Yapese'
        ],
        RaceType.ASIAN_PACIFIC: [
            'Asian (Pacific Islander)',
            'Carolinian',
            'Chamorro',
            'Chuukese',
            'Fijian',
            'Filipino',
            'Guamanian',
            'Guamanian Or Chamorro',
            'Guamanian or Chamorro',
            'Iwo Jiman',
            'Kiribati',
            'Kosraean',
            'Mariana Islander',
            'Marshallese',
            'Melanesian',
            'Micronesian',
            'Native Hawaiian',
            'New Hebrides',
            'Other Pacific Islander',
            'Pacific Islander',
            'Palauan',
            'Pohnpeian',
            'Polynesian',
            'Saipanese',
            'Samoan',
            'Papua New Guinean',
            'Tahitian',
            'Tokelauan',
            'Tongan'
        ],
        RaceType.ASIAN_INDIAN: [
            'Asian Indian',
            'Sri Lankan',
            'Sri lankan',
            'West Indian'
        ],
        RaceType.ASIAN_CHINESE: [
            'Chinese',
        ],
        RaceType.HISPANIC: [
            'Barbadian',
            'Dominica Islander',
            'Grenadian',
            'Haitian',
            'Hispanic/Latino',
            'Jamaican',
            'St Vincentian',
            'Trinidadian'
        ],
        RaceType.OTHER: [
            '',
            'Aa',
            'Ab',
            'Af',
            'Ag',
            'Ak',
            'Al',
            'Ap',
            'Ar',
            'Av',
            'Ay',
            'B',
            'B1',
            'B2',
            'B3',
            'B4',
            'B5',
            'B6',
            'B7',
            'B8',
            'B9',
            'Ba',
            'Bb',
            'Bc',
            'Bd',
            'Be',
            'Bf',
            'Bg',
            'Bh',
            'Bj',
            'Bk',
            'Bm',
            'Bn',
            'Bo',
            'Bp',
            'Bq',
            'Br',
            'Bs',
            'Bt',
            'Bu',
            'Bv',
            'Bw',
            'Bx',
            'By',
            'Bz',
            'I',
            'MSDW_NOT APPLICABLE',
            'MSDW_OTHER',
            'MSDW_UNKNOWN',
            'NOT AVAILABLE',
            'Non Hispanic',
            'O',
            'Other',
            'Pk',
            'Pl',
            'Pm',
            'Po',
            'Ps',
            'Pv',
            'U',
            'Unk',
            'Unknown',
            'W'
        ],
        RaceType.WHITE: [
            'Caucasian (White)',
            'White'
        ]
    }
    
    # value mapping
    data['race'] = (
        data.race.map({
            label: cat for cat, labels in RACE_MAPPING.items()
            for label in labels
        }).astype(pd.api.types.CategoricalDtype(RaceType))
    )
    
    # pre-encoding nan handling
    for column in ['gender', 'race']:
        enc = OneHotEncoder(sparse=False)
        transformed_data = enc.fit_transform(data[[column]])
        transformed_columns = pd.DataFrame(
            data=transformed_data, 
            columns=[f'{column}_{c}' for c in enc.categories_[0]]
        )
        data = data.join(transformed_columns)
        del data[column]
        
    label_encoded_data = data.copy()
    
    label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]] = label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]].fillna(False)
    
    scaled_data, _ = Scale().execute(data=label_encoded_data, target=target)
    
    imputed_data, _ = Impute().execute(data=scaled_data, imputation_method=morpher.config.imputers.DEFAULT)
    
    return imputed_data

data_loader = DataLoader(agg_func_regex, prepare_data_function)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [(x / 100) for x in range(5, 100, 5)]
observation_windows_occurring = [[x, -1] for x in range(-361, -1, 30)]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator if x[0] == x[2] and x[1] == x[3]]
targets = ['other_viral_infection_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.BORDERLINE, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-4 ovi tw binning - all features #2',
    version='34.1.1',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric_binned",
    bin_size=30,
    rfe__run=True,
    rfe__step_size=50
)
# Out:
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4d0d23c898>
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 3102 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 667.967ms
#
# Fitting estimator with 3052 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 568.8ms
#
# Fitting estimator with 3002 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 774.634ms
#
# Fitting estimator with 2952 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 891.786ms
#
# Fitting estimator with 2902 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 834.86ms
#
# Fitting estimator with 2852 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 104.654ms
#
# Fitting estimator with 2802 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 403.67ms
#
# Fitting estimator with 2752 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 787.739ms
#
# Fitting estimator with 2702 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 998.591ms
#
# Fitting estimator with 2652 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 598.535ms
#
# Fitting estimator with 2602 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 557.263ms
#
# Fitting estimator with 2552 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 872.657ms
#
# Fitting estimator with 2502 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.151ms
#
# Fitting estimator with 2452 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 459.349ms
#
# Fitting estimator with 2402 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 676.385ms
#
# Fitting estimator with 2352 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 563.261ms
#
# Fitting estimator with 2302 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 553.202ms
#
# Fitting estimator with 2252 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 488.653ms
#
# Fitting estimator with 2202 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 36.872ms
#
# Fitting estimator with 2152 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 292.717ms
#
# Fitting estimator with 2102 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 384.81ms
#
# Fitting estimator with 2052 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 20.81ms
#
# Fitting estimator with 2002 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 818.479ms
#
# Fitting estimator with 1952 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 129.235ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 772.001ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 251.182ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 841.712ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 386.697ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 5.143ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 830.351ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 727.342ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 936.029ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 126.305ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 73.032ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 139.883ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 65.368ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 67.619ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 554.806ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 788.802ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 549.099ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 767.402ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 819.025ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 528.485ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 445.587ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 610.938ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 825.157ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 624.702ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 809.992ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 607.16ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 137.716ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 570.681ms
#
# Fitting estimator with 3102 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 957.971ms
#
# Fitting estimator with 3052 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 81.969ms
#
# Fitting estimator with 3002 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 44.755ms
#
# Fitting estimator with 2952 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 976.636ms
#
# Fitting estimator with 2902 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 207.975ms
#
# Fitting estimator with 2852 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 193.081ms
#
# Fitting estimator with 2802 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 884.062ms
#
# Fitting estimator with 2752 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 958.869ms
#
# Fitting estimator with 2702 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 850.025ms
#
# Fitting estimator with 2652 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 926.749ms
#
# Fitting estimator with 2602 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 982.39ms
#
# Fitting estimator with 2552 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 938.141ms
#
# Fitting estimator with 2502 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 17.215ms
#
# Fitting estimator with 2452 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 895.58ms
#
# Fitting estimator with 2402 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 888.972ms
#
# Fitting estimator with 2352 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 893.744ms
#
# Fitting estimator with 2302 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 817.644ms
#
# Fitting estimator with 2252 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 861.121ms
#
# Fitting estimator with 2202 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 740.567ms
#
# Fitting estimator with 2152 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 791.761ms
#
# Fitting estimator with 2102 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 793.019ms
#
# Fitting estimator with 2052 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 572.114ms
#
# Fitting estimator with 2002 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 940.053ms
#
# Fitting estimator with 1952 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 918.888ms
#
# Fitting estimator with 1902 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 920.716ms
#
# Fitting estimator with 1852 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 983.154ms
#
# Fitting estimator with 1802 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 713.103ms
#
# Fitting estimator with 1752 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 764.838ms
#
# Fitting estimator with 1702 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 656.643ms
#
# Fitting estimator with 1652 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 693.898ms
#
# Fitting estimator with 1602 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 717.09ms
#
# Fitting estimator with 1552 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 709.006ms
#
# Fitting estimator with 1502 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 664.418ms
#
# Fitting estimator with 1452 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 906.812ms
#
# Fitting estimator with 1402 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 805.749ms
#
# Fitting estimator with 1352 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 522.572ms
#
# Fitting estimator with 1302 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 549.939ms
#
# Fitting estimator with 1252 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 507.204ms
#
# Fitting estimator with 1202 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 528.64ms
#
# Fitting estimator with 1152 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 427.545ms
#
# Fitting estimator with 1102 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 460.118ms
#
# Fitting estimator with 1052 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 389.625ms
#
# Fitting estimator with 1002 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 390.413ms
#
# Fitting estimator with 952 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 345.096ms
#
# Fitting estimator with 902 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 335.166ms
#
# Fitting estimator with 852 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 288.402ms
#
# Fitting estimator with 802 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 473.378ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 566.15ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 499.189ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 482.426ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 475.751ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 491.287ms
#
# *** Training of classifier ready. Time elapsed: 563.625ms
#
# Fitting estimator with 342 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 244.776ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 910.313ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 915.722ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 610.677ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 653.172ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 614.676ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 655.602ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 628.411ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 61.186ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.789ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 68.07ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 49.867ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 44.828ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 138.335ms
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 306.427ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 383.407ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 274.547ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 254.793ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 141.317ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 145.693ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 106.936ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 282.901ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 287.42ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 528.562ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 513.012ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 455.342ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 536.428ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 506.327ms
#
# Fitting estimator with 2942 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 968.628ms
#
# Fitting estimator with 2892 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 221.284ms
#
# Fitting estimator with 2842 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 131.08ms
#
# Fitting estimator with 2792 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 861.015ms
#
# Fitting estimator with 2742 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 911.132ms
#
# Fitting estimator with 2692 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 833.966ms
#
# Fitting estimator with 2642 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 981.101ms
#
# Fitting estimator with 2592 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 901.733ms
#
# Fitting estimator with 2542 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 876.698ms
#
# Fitting estimator with 2492 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 895.39ms
#
# Fitting estimator with 2442 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 883.269ms
#
# Fitting estimator with 2392 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 810.42ms
#
# Fitting estimator with 2342 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 852.402ms
#
# Fitting estimator with 2292 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 808.259ms
#
# Fitting estimator with 2242 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 881.747ms
#
# Fitting estimator with 2192 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 814.387ms
#
# Fitting estimator with 2142 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 791.193ms
#
# Fitting estimator with 2092 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 872.272ms
#
# Fitting estimator with 2042 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 946.299ms
#
# Fitting estimator with 1992 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 946.793ms
#
# Fitting estimator with 1942 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 895.363ms
#
# Fitting estimator with 1892 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 655.522ms
#
# Fitting estimator with 1842 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 684.317ms
#
# Fitting estimator with 1792 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 709.398ms
#
# Fitting estimator with 1742 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 699.188ms
#
# Fitting estimator with 1692 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 690.256ms
#
# Fitting estimator with 1642 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 736.831ms
#
# Fitting estimator with 1592 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 717.38ms
#
# Fitting estimator with 1542 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 636.634ms
#
# Fitting estimator with 1492 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 612.636ms
#
# Fitting estimator with 1442 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 564.289ms
#
# Fitting estimator with 1392 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 587.287ms
#
# Fitting estimator with 1342 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 543.962ms
#
# Fitting estimator with 1292 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 594.135ms
#
# Fitting estimator with 1242 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 592.559ms
#
# Fitting estimator with 1192 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 511.666ms
#
# Fitting estimator with 1142 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 425.365ms
#
# Fitting estimator with 1092 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 590.038ms
#
# Fitting estimator with 1042 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 614.373ms
#
# Fitting estimator with 992 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 443.922ms
#
# Fitting estimator with 942 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 352.287ms
#
# Fitting estimator with 892 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 280.576ms
#
# Fitting estimator with 842 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 348.395ms
#
# Fitting estimator with 792 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 412.356ms
#
# Fitting estimator with 742 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 292.79ms
#
# Fitting estimator with 692 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 288.499ms
#
# Fitting estimator with 642 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 265.683ms
#
# Fitting estimator with 592 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 183.872ms
#
# Fitting estimator with 542 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 152.03ms
#
# Fitting estimator with 492 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 116.806ms
#
# Fitting estimator with 442 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.762ms
#
# Fitting estimator with 392 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 11.934ms
#
# Fitting estimator with 342 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 954.855ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 967.838ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 966.058ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 150.417ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 905.763ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 249.599ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 168.51ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 230.947ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 975.936ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 993.046ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 966.229ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 938.43ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 947.597ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 482.908ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 514.787ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 460.227ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 474.414ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 469.756ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 572.746ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 515.173ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.9ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 484.588ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 492.344ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 510.89ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 563.746ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 555.507ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 569.649ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 608.89ms
#
# Fitting estimator with 2942 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 324.722ms
#
# Fitting estimator with 2892 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 306.276ms
#
# Fitting estimator with 2842 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 310.878ms
#
# Fitting estimator with 2792 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 285.11ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 278.032ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 285.722ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 369.777ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 377.278ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 367.753ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 375.151ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 382.665ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 147.719ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 157.656ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 144.848ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 187.081ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 148.491ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.006ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 509.918ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 457.86ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 443.57ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 480.566ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 456.287ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 447.282ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 459.636ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 650.203ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 522.892ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 250.565ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 282.897ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 260.169ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 231.291ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 231.963ms
# Fitting estimator with 2942 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 604.812ms
#
# Fitting estimator with 2892 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 610.813ms
#
# Fitting estimator with 2842 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 465.549ms
#
# Fitting estimator with 2792 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 446.052ms
#
# Fitting estimator with 2742 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 523.093ms
#
# Fitting estimator with 2692 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 437.48ms
#
# Fitting estimator with 2642 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 395.665ms
#
# Fitting estimator with 2592 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 458.244ms
#
# Fitting estimator with 2542 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 577.557ms
#
# Fitting estimator with 2492 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 367.279ms
#
# Fitting estimator with 2442 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 464.93ms
#
# Fitting estimator with 2392 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 357.445ms
#
# Fitting estimator with 2342 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 358.603ms
#
# Fitting estimator with 2292 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 297.272ms
#
# Fitting estimator with 2242 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 292.483ms
#
# Fitting estimator with 2192 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 301.78ms
#
# Fitting estimator with 2142 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 368.957ms
#
# Fitting estimator with 2092 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 423.344ms
#
# Fitting estimator with 2042 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 286.669ms
#
# Fitting estimator with 1992 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 282.982ms
#
# Fitting estimator with 1942 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 401.436ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 396.461ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 240.767ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 256.118ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 253.915ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 500.528ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 342.561ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 267.43ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 140.389ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 140.231ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 132.008ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 209.885ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 334.204ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 375.225ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 264.246ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 391.799ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 285.83ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 241.95ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 277.777ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 282.162ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 633.626ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 598.351ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 348.951ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 375.803ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 403.909ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 320.936ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 218.956ms
#
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 219.355ms
# Columns (10,17,18,19,23,26,30,34,63,82,89,91,93,94,95,96,103,110,111,112,115,118,119,120,127,130,134,135,136,137,143,163,164,170,226,234,238,239,277,303,304,305,308,310,314,318,325,337,343,344,345,349,365,380,385,406,411,415,417,420,427) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4d0d154cf8>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 2766 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 597.911ms
#
# Fitting estimator with 2716 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 995.585ms
#
# Fitting estimator with 2666 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 978.236ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 764.937ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 922.219ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 301.706ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 845.528ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.95ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 400.376ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 770.899ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 444.903ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 155.466ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 474.891ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 576.614ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 709.761ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 451.079ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 932.554ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 552.431ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 312.787ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 996.854ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 852.087ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 193.669ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 932.263ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 951.369ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 609.245ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 260.798ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 142.668ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 385.54ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 132.025ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 195.145ms
#
# Fitting estimator with 2766 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 926.142ms
#
# Fitting estimator with 2716 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 901.599ms
#
# Fitting estimator with 2666 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 870.788ms
#
# Fitting estimator with 2616 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 883.921ms
#
# Fitting estimator with 2566 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 752.438ms
#
# Fitting estimator with 2516 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 595.851ms
#
# Fitting estimator with 2466 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 65.014ms
#
# Fitting estimator with 2416 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 948.219ms
#
# Fitting estimator with 2366 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 700.679ms
#
# Fitting estimator with 2316 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 730.994ms
#
# Fitting estimator with 2266 features.
# ...
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.278ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.932ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 34.984ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 27.085ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 25.109ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 44.624ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 21.008ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 26.78ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.582ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.175ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 35.854ms
# Columns (2,3,11,13,15,16,20,23,24,27,31,33,36,37,38,40,44,52,57,60,61,67,70,78,85,86,88,89,90,92,93,94,103,104,105,106,109,110,111,112,114,115,116,117,118,122,123,124,125,126,151,152,158,164,166,168,173,177,185,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,218,219,220,221,222,229,232,238,239,241,242,243,244,246,247,248,249,250,251,252,253,254,255,256,258,259,261,262,265,266,267,268,269,270,271,272,273,274,278,279,280,281,283,284,285,286,287,290,291,292,297,298,306,310,311,315,316,317,336,347,349,350,351,366,368,375,378) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4d0d3e4358>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 279.209ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 261.389ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 294.305ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 282.459ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 288.856ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 302.727ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 281.415ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 144.869ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 151.864ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 149.338ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 151.343ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 150.235ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 283.542ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 278.72ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 291.179ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 305.718ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 278.062ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 290.66ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 296.615ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 295.411ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 290.337ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 293.658ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 209.086ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 208.719ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 232.599ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 211.835ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 210.3ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 455.261ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 450.513ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 508.944ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 522.182ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 495.629ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 496.768ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 490.69ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 286.384ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 301.071ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 307.869ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 285.154ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 298.206ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 476.72ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.26ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 463.28ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 462.832ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 443.97ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 447.225ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.247ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 441.288ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 467.793ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 467.007ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 412.222ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 384.083ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.766ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 376.807ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 386.111ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.349ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.129ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.513ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.512ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.738ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.438ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.866ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.361ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.371ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.318ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.042ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 1.932ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.845ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.691ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.215ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.682ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.935ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.184ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.917ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.244ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.949ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.432ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 4.525ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.321ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.895ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.454ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 3.718ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 53.755ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 39.999ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 25.123ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.39ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 14.879ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.457ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 16.513ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.893ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.745ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 11.584ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 15.077ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 13.658ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 25.633ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 25.332ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 41.441ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.197ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 29.069ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 33.22ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 22.361ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.544ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.856ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 23.599ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 28.041ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.878ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 17.872ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.943ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 19.435ms
# Columns (2,3,12,13,19,20,23,28,31,32,33,34,35,39,43,47,52,55,56,62,63,64,65,69,70,71,72,79,80,82,83,84,86,87,88,89,91,97,98,99,102,103,104,105,107,108,109,110,111,113,114,115,116,117,118,120,127,143,144,148,150,155,156,158,164,167,168,170,173,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,204,205,206,213,214,215,216,218,221,222,224,225,226,227,229,230,231,232,233,234,235,236,237,238,240,241,242,244,245,246,247,248,249,250,251,252,253,257,258,260,261,262,263,264,266,267,268,273,274,282,283,285,286,287,289,291,292,293,296,311,314,318,322,324,325,326,341,342,343,345,347,349,350,351,353) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7f4d0cb15d68>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 276.726ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pipeline.id
# Out:
# 198

# %% [markdown]
# # Results

# %%
get_training_results(198, sort_by='auc_roc_mean', metrics=['auc_roc_mean', 'auc_roc_std', 'precision_mean', 'recall_mean', 'auc_prc_mean'], n_rows=10000, response_type="pandas")
# Out:
#                          algorithm  auc_prc_mean  auc_roc_mean  auc_roc_std  \
# 0               LogisticRegression      0.694585      0.808255     0.029705
# 1               LogisticRegression      0.691757      0.804541     0.030117
# 2               LogisticRegression      0.690998      0.804394     0.030765
# 3               LogisticRegression      0.691083      0.803555     0.028825
# 4               LogisticRegression      0.657182      0.792901     0.039541
# 5               LogisticRegression      0.657987      0.790956     0.035046
# 6     GradientBoostingDecisionTree      0.676073      0.790688     0.038754
# 7               LogisticRegression      0.646713      0.786717     0.036511
# 8     GradientBoostingDecisionTree      0.680104      0.786397     0.036676
# 9     GradientBoostingDecisionTree      0.673237      0.785645     0.032826
# 10              LogisticRegression      0.637642      0.785531     0.035065
# 11              LogisticRegression      0.586175      0.784708     0.020820
# 12              LogisticRegression      0.651697      0.783449     0.032789
# 13              LogisticRegression      0.583975      0.782819     0.024272
# 14                    RandomForest      0.653884      0.782616     0.034327
# 15                    RandomForest      0.654074      0.782266     0.035861
# 16                    RandomForest      0.649015      0.782204     0.025423
# 17              LogisticRegression      0.659127      0.782026     0.019060
# 18    GradientBoostingDecisionTree      0.664931      0.781870     0.028751
# 19              LogisticRegression      0.649903      0.780687     0.030732
# 20              LogisticRegression      0.660127      0.780440     0.019215
# 21              LogisticRegression      0.648047      0.779628     0.033623
# 22              LogisticRegression      0.600247      0.778765     0.028252
# 23                    RandomForest      0.648009      0.778655     0.037332
# 24    GradientBoostingDecisionTree      0.665038      0.778551     0.033977
# 25              LogisticRegression      0.596123      0.778087     0.031729
# 26              LogisticRegression      0.646010      0.777961     0.035997
# 27    GradientBoostingDecisionTree      0.670902      0.777912     0.033433
# 28                    RandomForest      0.644699      0.777889     0.034251
# 29              LogisticRegression      0.600759      0.777643     0.027529
# ...                            ...           ...           ...          ...
# 4530  GradientBoostingDecisionTree      0.336513      0.576922     0.028849
# 4531  GradientBoostingDecisionTree      0.331001      0.576721     0.016364
# 4532  GradientBoostingDecisionTree      0.345613      0.576702     0.025355
# 4533  GradientBoostingDecisionTree      0.323652      0.576223     0.032196
# 4534                  DecisionTree      0.294676      0.575885     0.022046
# 4535                  DecisionTree      0.292668      0.575627     0.009659
# 4536  GradientBoostingDecisionTree      0.340750      0.575395     0.013540
# 4537  GradientBoostingDecisionTree      0.335093      0.574963     0.025408
# 4538  GradientBoostingDecisionTree      0.324925      0.574545     0.038240
# 4539                  DecisionTree      0.310564      0.574092     0.019103
# 4540                  DecisionTree      0.310570      0.574028     0.038849
# 4541                  DecisionTree      0.307242      0.573477     0.030823
# 4542                  DecisionTree      0.321096      0.573426     0.025262
# 4543  GradientBoostingDecisionTree      0.329051      0.573399     0.025305
# 4544                  DecisionTree      0.295300      0.573170     0.017457
# 4545  GradientBoostingDecisionTree      0.336977      0.572396     0.029954
# 4546  GradientBoostingDecisionTree      0.333519      0.572216     0.015191
# 4547                  DecisionTree      0.329057      0.572212     0.018936
# 4548                  DecisionTree      0.319079      0.571819     0.032970
# 4549  GradientBoostingDecisionTree      0.343815      0.571028     0.041441
# 4550  GradientBoostingDecisionTree      0.331577      0.570252     0.029295
# 4551  GradientBoostingDecisionTree      0.339865      0.569926     0.024430
# 4552  GradientBoostingDecisionTree      0.334593      0.569368     0.027063
# 4553                  DecisionTree      0.318255      0.567542     0.039071
# 4554                  DecisionTree      0.305075      0.567098     0.030708
# 4555  GradientBoostingDecisionTree      0.338602      0.566972     0.036208
# 4556                  DecisionTree      0.307981      0.566070     0.029922
# 4557  GradientBoostingDecisionTree      0.324299      0.566063     0.018518
# 4558                  DecisionTree      0.312247      0.550850     0.033768
# 4559                  DecisionTree      0.345167      0.539991     0.070771
#
#       precision_mean  recall_mean             sampler  \
# 0           0.583653     0.637548           NoSampler
# 1           0.585684     0.641026     BorderlineSMOTE
# 2           0.587617     0.623814   RandomOverSampler
# 3           0.581294     0.642706               SMOTE
# 4           0.572025     0.634055   RandomOverSampler
# 5           0.565791     0.628912           NoSampler
# 6           0.768718     0.407162           NoSampler
# 7           0.547126     0.644312               SMOTE
# 8           0.611121     0.542912   RandomOverSampler
# 9           0.652555     0.482832               SMOTE
# 10          0.525107     0.668361     BorderlineSMOTE
# 11          0.510053     0.646080           NoSampler
# 12          0.548676     0.618597           NoSampler
# 13          0.510459     0.640819   RandomOverSampler
# 14          0.631262     0.530946   RandomOverSampler
# 15          0.660659     0.489699           NoSampler
# 16          0.674485     0.477719               SMOTE
# 17          0.564188     0.616888   RandomOverSampler
# 18          0.645861     0.491409     BorderlineSMOTE
# 19          0.550248     0.615164   RandomOverSampler
# 20          0.559278     0.620336           NoSampler
# 21          0.528933     0.613395     BorderlineSMOTE
# 22          0.519034     0.630710   RandomOverSampler
# 23          0.638920     0.477660           NoSampler
# 24          0.767150     0.378014           NoSampler
# 25          0.519092     0.651297               SMOTE
# 26          0.530802     0.622016               SMOTE
# 27          0.614036     0.541173   RandomOverSampler
# 28          0.606532     0.500000   RandomOverSampler
# 29          0.517548     0.640981           NoSampler
# ...              ...          ...                 ...
# 4530        0.331197     0.570321  RandomUnderSampler
# 4531        0.327466     0.592676  RandomUnderSampler
# 4532        0.335897     0.601208  RandomUnderSampler
# 4533        0.335842     0.594282  RandomUnderSampler
# 4534        0.336038     0.618597               SMOTE
# 4535        0.335831     0.582479     BorderlineSMOTE
# 4536        0.329625     0.587504  RandomUnderSampler
# 4537        0.338520     0.580681  RandomUnderSampler
# 4538        0.333443     0.554760  RandomUnderSampler
# 4539        0.329524     0.603124  RandomUnderSampler
# 4540        0.335155     0.582346  RandomUnderSampler
# 4541        0.337145     0.548011  RandomUnderSampler
# 4542        0.339780     0.579001  RandomUnderSampler
# 4543        0.324041     0.565164  RandomUnderSampler
# 4544        0.338090     0.585780     BorderlineSMOTE
# 4545        0.341570     0.573666  RandomUnderSampler
# 4546        0.322770     0.563498  RandomUnderSampler
# 4547        0.340484     0.491379   RandomOverSampler
# 4548        0.340592     0.529134     BorderlineSMOTE
# 4549        0.331891     0.565134  RandomUnderSampler
# 4550        0.332757     0.582346  RandomUnderSampler
# 4551        0.315754     0.547981  RandomUnderSampler
# 4552        0.335266     0.575464  RandomUnderSampler
# 4553        0.339345     0.558518  RandomUnderSampler
# 4554        0.334922     0.572311  RandomUnderSampler
# 4555        0.318154     0.561701  RandomUnderSampler
# 4556        0.331372     0.570483  RandomUnderSampler
# 4557        0.325000     0.558164  RandomUnderSampler
# 4558        0.306393     0.510492  RandomUnderSampler
# 4559        0.359074     0.462261     BorderlineSMOTE
#
#                                                                target  \
# 0     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 1     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 2     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 3     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 5     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 6     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 7     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 8     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 9     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 10    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 11    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 12    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 13    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 14    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 15    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 16    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 17    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 18    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 19    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 20    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 21    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 22    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 23    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 24    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 25    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 26    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 27    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 28    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 29    other_viral_infection_onset_from_0_days_after_to_365_days_after
# ...                                                               ...
# 4530  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4531  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4532  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4533  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4534  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4535  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4536  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4537  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4538  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4539  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4540  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4541  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4542  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4543  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4544  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4545  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4546  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4547  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4548  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4549  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4550  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4551  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4552  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4553  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4554  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4555  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4556  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4557  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4558  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4559  other_viral_infection_onset_from_0_days_after_to_365_days_after
#
#       threshold_numeric  threshold_occurring  window_start_numeric  \
# 0                  0.05                 0.05                  -361
# 1                  0.05                 0.05                  -361
# 2                  0.05                 0.05                  -361
# 3                  0.05                 0.05                  -361
# 4                  0.05                 0.05                  -211
# 5                  0.05                 0.05                  -211
# 6                  0.05                 0.05                  -331
# 7                  0.05                 0.05                  -211
# 8                  0.05                 0.05                  -331
# 9                  0.05                 0.05                  -331
# 10                 0.05                 0.05                  -211
# 11                 0.10                 0.10                  -331
# 12                 0.05                 0.05                  -241
# 13                 0.10                 0.10                  -331
# 14                 0.05                 0.05                  -361
# 15                 0.05                 0.05                  -361
# 16                 0.05                 0.05                  -361
# 17                 0.05                 0.05                  -331
# 18                 0.05                 0.05                  -331
# 19                 0.05                 0.05                  -241
# 20                 0.05                 0.05                  -331
# 21                 0.05                 0.05                  -241
# 22                 0.05                 0.05                  -151
# 23                 0.05                 0.05                  -331
# 24                 0.05                 0.05                  -271
# 25                 0.05                 0.05                  -151
# 26                 0.05                 0.05                  -241
# 27                 0.05                 0.05                  -271
# 28                 0.05                 0.05                  -301
# 29                 0.05                 0.05                  -151
# ...                 ...                  ...                   ...
# 4530               0.80                 0.80                  -151
# 4531               0.65                 0.65                   -61
# 4532               0.80                 0.80                   -31
# 4533               0.70                 0.70                   -31
# 4534               0.70                 0.70                  -151
# 4535               0.80                 0.80                   -31
# 4536               0.70                 0.70                  -121
# 4537               0.75                 0.75                   -61
# 4538               0.70                 0.70                   -91
# 4539               0.85                 0.85                  -271
# 4540               0.85                 0.85                   -61
# 4541               0.75                 0.75                   -31
# 4542               0.80                 0.80                  -151
# 4543               0.95                 0.95                  -241
# 4544               0.75                 0.75                   -91
# 4545               0.85                 0.85                   -61
# 4546               0.95                 0.95                   -91
# 4547               0.70                 0.70                  -151
# 4548               0.50                 0.50                   -31
# 4549               0.80                 0.80                  -121
# 4550               0.80                 0.80                   -91
# 4551               0.85                 0.85                  -301
# 4552               0.95                 0.95                  -271
# 4553               0.80                 0.80                   -61
# 4554               0.75                 0.75                  -271
# 4555               0.85                 0.85                  -121
# 4556               0.75                 0.75                  -181
# 4557               0.85                 0.85                   -31
# 4558               0.35                 0.35                   -61
# 4559               0.10                 0.10                  -271
#
#       window_start_occurring
# 0                       -361
# 1                       -361
# 2                       -361
# 3                       -361
# 4                       -211
# 5                       -211
# 6                       -331
# 7                       -211
# 8                       -331
# 9                       -331
# 10                      -211
# 11                      -331
# 12                      -241
# 13                      -331
# 14                      -361
# 15                      -361
# 16                      -361
# 17                      -331
# 18                      -331
# 19                      -241
# 20                      -331
# 21                      -241
# 22                      -151
# 23                      -331
# 24                      -271
# 25                      -151
# 26                      -241
# 27                      -271
# 28                      -301
# 29                      -151
# ...                      ...
# 4530                    -151
# 4531                     -61
# 4532                     -31
# 4533                     -31
# 4534                    -151
# 4535                     -31
# 4536                    -121
# 4537                     -61
# 4538                     -91
# 4539                    -271
# 4540                     -61
# 4541                     -31
# 4542                    -151
# 4543                    -241
# 4544                     -91
# 4545                     -61
# 4546                     -91
# 4547                    -151
# 4548                     -31
# 4549                    -121
# 4550                     -91
# 4551                    -301
# 4552                    -271
# 4553                     -61
# 4554                    -271
# 4555                    -121
# 4556                    -181
# 4557                     -31
# 4558                     -61
# 4559                    -271
#
# [4560 rows x 12 columns]
