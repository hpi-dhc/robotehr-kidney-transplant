# %%
# %run ../00_default_options.ipynb

# %%
from robotehr.api.training import get_training_results
from robotehr.pipelines import training
from robotehr.models.cohort import Cohort, OnsetDataFrame
from robotehr.models.data import FeaturePipeline
from robotehr.pipelines.supporters.preprocessing import DataLoader
# Out:
# [2020-05-21 10:12:44,606] INFO in __init__: RobotEHR API

# %%
cohort = Cohort.load(id=1)

# %%
onset_dataframe = OnsetDataFrame.load(id=18)

# %%
feature_pipeline = FeaturePipeline.load(id=22)

# %%
import morpher.config
from morpher.jobs import *
# Out:
# Using TensorFlow backend.

# %%
regexes = [
    'any__Diagnosis__',
    #'any__Procedure__', 
    #'any__Drug__', 
    #'any__Material__', 
    #'any__Encounter__', 
    #'any__AlcoholUse__', 
    #'any__DrugUse__', 
    #'any__TobaccoUse__',
]

agg_func_regex = ""
for r in regexes:
    agg_func_regex += r + "|"
agg_func_regex = agg_func_regex[:-1]

def prepare_data_function(data, target):
    import morpher
    from morpher.jobs import Impute, Scale
    from sklearn.preprocessing import OneHotEncoder
    from enum import Enum
    
    # remove unused features
    del data['medical_record_number']
    del data['mother_account_number']
    del data['date_of_birth']
    del data['month_of_birth']
    del data['patient_ethnic_group']
    del data['religion']
    del data['address_zip']
    del data['deceased_indicator']
    del data['marital_status_code']
    
    class RaceType(str, Enum):
        AFRICAN = 'African'
        AMERICAN_BLACK = 'Black or African-American'
        AMERICAN_NATIVE = 'Native American'
        ASIAN = 'Asian'
        ASIAN_PACIFIC = 'Asian Pacific'
        ASIAN_INDIAN = 'Asian Indian'
        ASIAN_CHINESE = 'Asian Chinese'
        HISPANIC = 'Hispanic or Latino'
        OTHER = 'Other'
        WHITE = 'White'
    
    RACE_MAPPING = {
        RaceType.AFRICAN: [
            'Cape Verdian',
            'Congolese',
            'Eritrean',
            'Ethiopian',
            'Gabonian',
            'Ghanaian',
            'Guinean',
            'Ivory Coastian',
            'Kenyan',
            'Liberian',
            'Madagascar',
            'Malian',
            'Nigerian',
            'Other: East African',
            'Other: North African',
            'Other: South African',
            'Other: West African',
            'Senegalese',
            'Sierra Leonean',
            'Somalian',
            'Sudanese',
            'Tanzanian',
            'Togolese',
            'Ugandan',
            'Zimbabwean'
        ],
        RaceType.AMERICAN_BLACK: [
            'African American (Black)',
            'African-American',
            'Black Or African-American',
            'Black or African - American',
        ],
        RaceType.AMERICAN_NATIVE: [
            'American (Indian/Alaskan)',
            'Native American'
        ],
        RaceType.ASIAN: [
            'Asian',
            'Bangladeshi',
            'Bhutanese',
            'Burmese',
            'Cambodian',
            'Hmong',
            'Indonesian',
            'Japanese',
            'Korean',
            'Laotian',
            'Malaysian',
            'Maldivian',
            'Nepalese',
            'Okinawan',
            'Pakistani',
            'Singaporean',
            'Taiwanese',
            'Thai',
            'Vietnamese',
            'Yapese'
        ],
        RaceType.ASIAN_PACIFIC: [
            'Asian (Pacific Islander)',
            'Carolinian',
            'Chamorro',
            'Chuukese',
            'Fijian',
            'Filipino',
            'Guamanian',
            'Guamanian Or Chamorro',
            'Guamanian or Chamorro',
            'Iwo Jiman',
            'Kiribati',
            'Kosraean',
            'Mariana Islander',
            'Marshallese',
            'Melanesian',
            'Micronesian',
            'Native Hawaiian',
            'New Hebrides',
            'Other Pacific Islander',
            'Pacific Islander',
            'Palauan',
            'Pohnpeian',
            'Polynesian',
            'Saipanese',
            'Samoan',
            'Papua New Guinean',
            'Tahitian',
            'Tokelauan',
            'Tongan'
        ],
        RaceType.ASIAN_INDIAN: [
            'Asian Indian',
            'Sri Lankan',
            'Sri lankan',
            'West Indian'
        ],
        RaceType.ASIAN_CHINESE: [
            'Chinese',
        ],
        RaceType.HISPANIC: [
            'Barbadian',
            'Dominica Islander',
            'Grenadian',
            'Haitian',
            'Hispanic/Latino',
            'Jamaican',
            'St Vincentian',
            'Trinidadian'
        ],
        RaceType.OTHER: [
            '',
            'Aa',
            'Ab',
            'Af',
            'Ag',
            'Ak',
            'Al',
            'Ap',
            'Ar',
            'Av',
            'Ay',
            'B',
            'B1',
            'B2',
            'B3',
            'B4',
            'B5',
            'B6',
            'B7',
            'B8',
            'B9',
            'Ba',
            'Bb',
            'Bc',
            'Bd',
            'Be',
            'Bf',
            'Bg',
            'Bh',
            'Bj',
            'Bk',
            'Bm',
            'Bn',
            'Bo',
            'Bp',
            'Bq',
            'Br',
            'Bs',
            'Bt',
            'Bu',
            'Bv',
            'Bw',
            'Bx',
            'By',
            'Bz',
            'I',
            'MSDW_NOT APPLICABLE',
            'MSDW_OTHER',
            'MSDW_UNKNOWN',
            'NOT AVAILABLE',
            'Non Hispanic',
            'O',
            'Other',
            'Pk',
            'Pl',
            'Pm',
            'Po',
            'Ps',
            'Pv',
            'U',
            'Unk',
            'Unknown',
            'W'
        ],
        RaceType.WHITE: [
            'Caucasian (White)',
            'White'
        ]
    }
    
    # value mapping
    data['race'] = (
        data.race.map({
            label: cat for cat, labels in RACE_MAPPING.items()
            for label in labels
        }).astype(pd.api.types.CategoricalDtype(RaceType))
    )
    
    # pre-encoding nan handling
    for column in ['gender', 'race']:
        enc = OneHotEncoder(sparse=False)
        transformed_data = enc.fit_transform(data[[column]])
        transformed_columns = pd.DataFrame(
            data=transformed_data, 
            columns=[f'{column}_{c}' for c in enc.categories_[0]]
        )
        data = data.join(transformed_columns)
        del data[column]
        
    label_encoded_data = data.copy()
    
    label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]] = label_encoded_data[label_encoded_data.columns[label_encoded_data.columns.str.contains('any')]].fillna(False)
    
    scaled_data, _ = Scale().execute(data=label_encoded_data, target=target)
    
    imputed_data, _ = Impute().execute(data=scaled_data, imputation_method=morpher.config.imputers.DEFAULT)
    
    return imputed_data

data_loader = DataLoader(agg_func_regex, prepare_data_function)

# %%
from itertools import product

# %%
thresholds_numeric = [(x / 100) for x in range(5, 100, 5)]
observation_windows_numeric = [[x, -1] for x in range(-361, -1, 30)]
thresholds_occurring = [0.05]
observation_windows_occurring = [[-361, -1]]

# %%
iterator = product(
    thresholds_numeric,
    observation_windows_numeric,
    thresholds_occurring,
    observation_windows_occurring
)

configs = [x for x in iterator]
targets = ['other_viral_infection_onset_from_0_days_after_to_365_days_after']
algorithms = [morpher.config.algorithms.GBDT, morpher.config.algorithms.RF, morpher.config.algorithms.DT, morpher.config.algorithms.LR]
samplers = [morpher.config.samplers.RANDOM, morpher.config.samplers.URANDOM, morpher.config.samplers.BORDERLINE, morpher.config.samplers.SMOTE, morpher.config.samplers.NOSAMPLER]

# %%
pipeline = training.execute(
    comment='baseline-5 ovi time series + numeric focus',
    version='35.0.0',
    cohort=cohort,
    onset_dataframe=onset_dataframe,
    feature_pipeline=feature_pipeline,
    data_loader=data_loader,
    observation_iterator=configs,
    targets=targets,
    algorithms=algorithms,
    samplers=samplers,
    feature_type_occurring="occurring",
    feature_type_numeric="numeric_time_series",
    rfe__run=True,
    rfe__step_size=50
)
# Out:
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fae8e3ff710>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 299.384ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 323.313ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 596.843ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 193.165ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 109.545ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 177.429ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 269.783ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 493.43ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 739.047ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 781.082ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 21.657ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 289.031ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 427.579ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 159.509ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 464.419ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 380.227ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 848.007ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 493.456ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 810.626ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 349.183ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 397.508ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 284.107ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 789.353ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 527.122ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 770.25ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 578.716ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 698.077ms
#
# Fitting estimator with 372 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 25.55ms
#
# Fitting estimator with 322 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 333.253ms
#
# Fitting estimator with 272 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 309.191ms
#
# Fitting estimator with 222 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 696.205ms
#
# Fitting estimator with 172 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 217.57ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 314.053ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 504.46ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 813.172ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 549.508ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 361.077ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 564.508ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 314.51ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 660.912ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 598.541ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 581.173ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 206.666ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 326.698ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 856.657ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 420.71ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 563.491ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 893.699ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 634.989ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 563.406ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 616.539ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 158.586ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 740.238ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 673.446ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 135.794ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 79.976ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 682.379ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 925.499ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 952.456ms
#
# Fitting estimator with 372 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 76.938ms
#
# Fitting estimator with 322 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 76.225ms
#
# Fitting estimator with 272 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.507ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 48.988ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.692ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 65.443ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 36.009ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 32.612ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.242ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.612ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 27.849ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 19.141ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 33.771ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.687ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.451ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 80.557ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 97.043ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.184ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 46.897ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 52.43ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 51.106ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 97.69ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 98.258ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 85.347ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 115.101ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.996ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 47.897ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 48.148ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.557ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 41.03ms
#
# Fitting estimator with 372 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 445.951ms
#
# Fitting estimator with 322 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 795.174ms
#
# Fitting estimator with 272 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 872.206ms
#
# Fitting estimator with 222 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 168.913ms
#
# Fitting estimator with 172 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 162.299ms
#
# Fitting estimator with 122 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 930.055ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 558.467ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 412.997ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 907.914ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 903.793ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 316.668ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 866.697ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 146.41ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 958.085ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 236.56ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 269.164ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 284.128ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 694.393ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 828.088ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 345.158ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 549.832ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 208.07ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 959.764ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 795.781ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 614.624ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 418.126ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 217.843ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 509.441ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 663.145ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 368.722ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 674.915ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 511.36ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 487.757ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fae8e3b33c8>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 372 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 754.378ms
#
# Fitting estimator with 322 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 85.399ms
#
# Fitting estimator with 272 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 450.43ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 246.936ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 382.6ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 360.658ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.594ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 775.895ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 997.736ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 91.302ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 2.357ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 8.81ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 74.016ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.937ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 83.58ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 555.032ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 141.803ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 677.684ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 636.821ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 555.089ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 231.446ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 91.024ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 147.204ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 443.735ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 367.693ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 252.409ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 149.424ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.587ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 154.642ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 12.379ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 466.153ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 530.801ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 637.405ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 496.328ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 741.922ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 647.616ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 685.126ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 878.526ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 709.392ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 778.423ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 729.377ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 764.193ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 600.391ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 41.755ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 988.605ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 424.964ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 995.768ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 780.72ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 923.783ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 334.519ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 9.511ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 195.594ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 317.691ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 156.463ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 142.059ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 124.746ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 121.89ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 74.725ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 72.542ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 103.17ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 103.051ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 110.718ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 101.71ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 105.066ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 56.661ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.779ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 37.177ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 51.146ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 52.611ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 72.781ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.465ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 72.22ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 79.776ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 76.409ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 77.559ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.888ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 70.843ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 83.161ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 80.271ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 70.907ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 60.536ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 76.392ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 44.084ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 33.834ms
#
# Fitting estimator with 372 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 460.959ms
#
# Fitting estimator with 322 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 299.168ms
#
# Fitting estimator with 272 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 849.841ms
#
# Fitting estimator with 222 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 620.322ms
#
# Fitting estimator with 172 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 480.897ms
#
# Fitting estimator with 122 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 160.527ms
#
# Fitting estimator with 72 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 885.173ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 630.006ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 665.268ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 897.511ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 657.447ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 510.242ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 420.508ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 250.18ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 502.598ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 350.574ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 261.77ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 972.484ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 764.705ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 873.136ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 186.349ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 858.138ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 781.278ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 725.147ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 60.309ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 929.988ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 645.811ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 718.062ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 566.967ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 800.831ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 739.695ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 618.315ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 658.454ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 548.64ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fae8e478908>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 370 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 222.941ms
#
# Fitting estimator with 320 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 905.463ms
#
# Fitting estimator with 270 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 469.897ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 904.786ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 140.051ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 837.452ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 759.655ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 751.649ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 709.935ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 760.545ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 419.866ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 52.544ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 355.443ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 655.346ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.127ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 889.85ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 202.981ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 107.086ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 428.973ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 328.463ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.411ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 104.918ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 496.059ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 314.732ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 143.941ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 555.211ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 784.468ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 297.82ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 98.454ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 943.117ms
#
# Fitting estimator with 370 features.
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 230.749ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 51.096ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 731.915ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.596ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 94.593ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 539.748ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 559.436ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 80.062ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 306.079ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 693.972ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 660.505ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 672.816ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 692.026ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 938.848ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 983.227ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 866.84ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 689.33ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 116.482ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 215.083ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 713.124ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 311.802ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 843.766ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 772.732ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 60.777ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 145.812ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 183.501ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 44.788ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 116.683ms
#
# Fitting estimator with 370 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 74.268ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 83.307ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 67.344ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 93.675ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 109.478ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 91.108ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 112.951ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 84.01ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 35.011ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 33.884ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 30.698ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 43.063ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 34.113ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 130.856ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 133.196ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 122.768ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 62.489ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 63.816ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 60.505ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 65.661ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.94ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 59.904ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 64.606ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 57.705ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 75.868ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 36.605ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.948ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.317ms
#
# Fitting estimator with 370 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 788.76ms
#
# Fitting estimator with 320 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 953.907ms
#
# Fitting estimator with 270 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 231.577ms
#
# Fitting estimator with 220 features.
# *** Training of model 'LogisticRegression' started.
# lbfgs failed to converge. Increase the number of iterations.
# *** Training of classifier ready. Time elapsed: 501.822ms
#
# Fitting estimator with 170 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 233.726ms
#
# Fitting estimator with 120 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 426.031ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 109.776ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 633.214ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 534.563ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 912.512ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 32.163ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 452.037ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 675.406ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 414.557ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 718.401ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 213.782ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 29.971ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 985.775ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 199.917ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 728.988ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 365.702ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 894.422ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 305.264ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 391.408ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 305.058ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 331.894ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 332.458ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 192.868ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 153.786ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 84.484ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 66.114ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 102.783ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 91.2ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fae8e46c9b0>
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fetching data for Patient (...)
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 364 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 634.613ms
#
# Fitting estimator with 314 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 257.433ms
#
# Fitting estimator with 264 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 838.645ms
#
# Fitting estimator with 214 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 574.392ms
#
# Fitting estimator with 164 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 259.88ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 923.173ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 944.12ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 281.097ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 273.557ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 306.996ms
#
# ...
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 665.07ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 532.284ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 606.807ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 544.245ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 518.431ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 429.901ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 324.466ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 285.899ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 379.835ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 526.186ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 223.559ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 319.944ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 427.638ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 642.932ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 700.49ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# Fetching data for <fiber.condition.mrns.MRNs object at 0x7fae8e458240>
# Fetching data for Patient (...)
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Data with input dtype bool, float64 were all converted to float64 by StandardScaler.
# Fitting estimator with 130 features.
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 924.899ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 711.713ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 326.038ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 479.331ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 426.082ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 926.429ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 279.289ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 625.198ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 551.26ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 540.534ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 530.893ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 547.303ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 538.872ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 416.103ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 420.312ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 438.298ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 416.319ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 407.082ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 582.73ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 507.332ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 449.507ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 415.593ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 494.89ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 830.425ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 835.721ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 816.912ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 845.287ms
#
# *** Training of model 'GradientBoostingClassifier' started.
# *** Training of classifier ready. Time elapsed: 826.948ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 322.955ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 432.48ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 235.239ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 772.08ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 528.813ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 705.208ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 225.386ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 648.639ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 671.947ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 670.138ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 649.935ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 638.541ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 421.874ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 432.331ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 424.17ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 438.567ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 379.852ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 386.056ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 378.101ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 377.755ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 400.702ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 385.801ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 959.844ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 927.733ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 956.788ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 542.48ms
#
# *** Training of model 'RandomForestClassifier' started.
# *** Training of classifier ready. Time elapsed: 748.953ms
#
# Fitting estimator with 130 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 118.72ms
#
# Fitting estimator with 80 features.
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 82.233ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.094ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 49.825ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 69.33ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 73.277ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 86.772ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 31.016ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 40.382ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 48.255ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 10.728ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 21.585ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 18.979ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 28.134ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 39.085ms
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 60.477ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 78.688ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 39.175ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 39.467ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 79.66ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 40.029ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 30.387ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 39.57ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 30.853ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 59.028ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 20.594ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.414ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 29.744ms
#
# *** Training of model 'DecisionTreeClassifier' started.
# *** Training of classifier ready. Time elapsed: 38.372ms
#
# Fitting estimator with 130 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 647.026ms
#
# Fitting estimator with 80 features.
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 853.102ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 526.027ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 352.16ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 438.323ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 533.645ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 80.102ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 491.223ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 637.688ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 233.515ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 12.607ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 304.321ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 426.706ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 668.439ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 413.81ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 628.602ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 506.69ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 999.448ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 123.277ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 298.343ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 58.8ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 39.66ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 154.727ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 820.725ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 288.857ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 38.883ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 830.91ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 443.725ms
#
# *** Training of model 'LogisticRegression' started.
# *** Training of classifier ready. Time elapsed: 46.106ms
# Columns (11,18,19,20,24,35,64,83,90,92,94,96,97,106,114,117,120,125,126,133,136,140,141,142,143,144,150,178,235,244,248,288,311,317,320,325,326,330,334,341,353,359,360,361,365,402,421,425,430,434,436,439,446) have mixed types. Specify dtype option on import or set low_memory=False.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
pipeline.id
# Out:
# 199

# %% [markdown]
# # Results

# %%
from robotehr.api.training import get_training_results
get_training_results(199, sort_by='auc_roc_mean', metrics=['auc_roc_mean', 'precision_mean', 'auc_prc_mean', 'recall_mean'], n_rows=10000, response_type="pandas")
# Out:
#                          algorithm  auc_prc_mean  auc_roc_mean  \
# 0               LogisticRegression      0.677787      0.787222
# 1               LogisticRegression      0.675260      0.785627
# 2               LogisticRegression      0.663593      0.785389
# 3               LogisticRegression      0.672240      0.784205
# 4               LogisticRegression      0.673573      0.784032
# 5               LogisticRegression      0.663423      0.782987
# 6               LogisticRegression      0.669207      0.782315
# 7               LogisticRegression      0.671467      0.781832
# 8               LogisticRegression      0.672763      0.781560
# 9               LogisticRegression      0.669494      0.780835
# 10              LogisticRegression      0.672540      0.780680
# 11              LogisticRegression      0.673667      0.780572
# 12              LogisticRegression      0.665014      0.780319
# 13              LogisticRegression      0.655315      0.780087
# 14              LogisticRegression      0.657828      0.779530
# 15              LogisticRegression      0.667155      0.779005
# 16              LogisticRegression      0.657230      0.778834
# 17              LogisticRegression      0.665531      0.778648
# 18              LogisticRegression      0.662222      0.778428
# 19              LogisticRegression      0.660739      0.777957
# 20              LogisticRegression      0.658985      0.777651
# 21              LogisticRegression      0.666301      0.777583
# 22              LogisticRegression      0.656120      0.777549
# 23              LogisticRegression      0.658087      0.777272
# 24              LogisticRegression      0.664584      0.777060
# 25              LogisticRegression      0.663084      0.776938
# 26              LogisticRegression      0.663127      0.776752
# 27    GradientBoostingDecisionTree      0.661356      0.776418
# 28              LogisticRegression      0.662881      0.776201
# 29              LogisticRegression      0.666973      0.775885
# ...                            ...           ...           ...
# 4530                  DecisionTree      0.584399      0.656782
# 4531                  DecisionTree      0.565207      0.656546
# 4532                  DecisionTree      0.574707      0.656376
# 4533                  DecisionTree      0.570266      0.656041
# 4534                  DecisionTree      0.580849      0.655819
# 4535                  DecisionTree      0.572475      0.655027
# 4536                  DecisionTree      0.576694      0.654911
# 4537                  DecisionTree      0.566175      0.654655
# 4538                  DecisionTree      0.566861      0.654544
# 4539                  DecisionTree      0.564317      0.654361
# 4540                  DecisionTree      0.566292      0.654298
# 4541                  DecisionTree      0.565245      0.654277
# 4542                  DecisionTree      0.569527      0.654100
# 4543                  DecisionTree      0.572493      0.654077
# 4544                  DecisionTree      0.557706      0.653133
# 4545                  DecisionTree      0.578833      0.652930
# 4546                  DecisionTree      0.572048      0.652915
# 4547                  DecisionTree      0.560882      0.652813
# 4548                  DecisionTree      0.567928      0.652494
# 4549                  DecisionTree      0.557882      0.652028
# 4550                  DecisionTree      0.567451      0.651881
# 4551                  DecisionTree      0.566419      0.651573
# 4552                  DecisionTree      0.564888      0.651260
# 4553                  DecisionTree      0.566107      0.650613
# 4554                  DecisionTree      0.543564      0.648191
# 4555                  DecisionTree      0.558027      0.647856
# 4556                  DecisionTree      0.544086      0.646454
# 4557                  DecisionTree      0.562520      0.646409
# 4558                  DecisionTree      0.559755      0.645753
# 4559                  DecisionTree      0.563329      0.644371
#
#       precision_mean  recall_mean             sampler  \
# 0           0.559962     0.634070           NoSampler
# 1           0.556402     0.632346               SMOTE
# 2           0.541733     0.630578           NoSampler
# 3           0.530277     0.618420           NoSampler
# 4           0.569185     0.625508   RandomOverSampler
# 5           0.530361     0.622001   RandomOverSampler
# 6           0.542695     0.611553               SMOTE
# 7           0.541271     0.604775           NoSampler
# 8           0.547218     0.649514     BorderlineSMOTE
# 9           0.540921     0.621824   RandomOverSampler
# 10          0.539965     0.634011  RandomUnderSampler
# 11          0.554368     0.623696           NoSampler
# 12          0.538176     0.616858           NoSampler
# 13          0.534836     0.597922           NoSampler
# 14          0.524953     0.621986               SMOTE
# 15          0.539547     0.616844           NoSampler
# 16          0.534954     0.613336           NoSampler
# 17          0.526584     0.611730   RandomOverSampler
# 18          0.552626     0.609917   RandomOverSampler
# 19          0.531483     0.616844           NoSampler
# 20          0.538048     0.608267           NoSampler
# 21          0.527778     0.608282               SMOTE
# 22          0.503753     0.652947     BorderlineSMOTE
# 23          0.522685     0.644297  RandomUnderSampler
# 24          0.525212     0.615149   RandomOverSampler
# 25          0.514094     0.627233               SMOTE
# 26          0.547082     0.625435           NoSampler
# 27          0.721652     0.374551           NoSampler
# 28          0.548175     0.613380           NoSampler
# 29          0.533561     0.618494               SMOTE
# ...              ...          ...                 ...
# 4530        0.721976     0.333230               SMOTE
# 4531        0.483082     0.474079   RandomOverSampler
# 4532        0.514083     0.479369   RandomOverSampler
# 4533        0.497974     0.456867     BorderlineSMOTE
# 4534        0.640499     0.357368               SMOTE
# 4535        0.690182     0.338285     BorderlineSMOTE
# 4536        0.658137     0.367654     BorderlineSMOTE
# 4537        0.524506     0.443236           NoSampler
# 4538        0.519371     0.420778               SMOTE
# 4539        0.505757     0.446670   RandomOverSampler
# 4540        0.650339     0.365738               SMOTE
# 4541        0.586800     0.340274               SMOTE
# 4542        0.547398     0.412216     BorderlineSMOTE
# 4543        0.460013     0.501680           NoSampler
# 4544        0.476178     0.477557   RandomOverSampler
# 4545        0.652079     0.377940     BorderlineSMOTE
# 4546        0.679222     0.341615     BorderlineSMOTE
# 4547        0.587727     0.350457               SMOTE
# 4548        0.618861     0.372797     BorderlineSMOTE
# 4549        0.420360     0.498143   RandomOverSampler
# 4550        0.494850     0.479119   RandomOverSampler
# 4551        0.554602     0.444842     BorderlineSMOTE
# 4552        0.578354     0.400192     BorderlineSMOTE
# 4553        0.678276     0.340186               SMOTE
# 4554        0.443700     0.469039   RandomOverSampler
# 4555        0.472656     0.455335           NoSampler
# 4556        0.445133     0.543045   RandomOverSampler
# 4557        0.495415     0.465679           NoSampler
# 4558        0.574205     0.362496     BorderlineSMOTE
# 4559        0.526787     0.443207   RandomOverSampler
#
#                                                                target  \
# 0     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 1     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 2     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 3     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 5     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 6     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 7     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 8     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 9     other_viral_infection_onset_from_0_days_after_to_365_days_after
# 10    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 11    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 12    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 13    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 14    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 15    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 16    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 17    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 18    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 19    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 20    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 21    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 22    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 23    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 24    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 25    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 26    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 27    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 28    other_viral_infection_onset_from_0_days_after_to_365_days_after
# 29    other_viral_infection_onset_from_0_days_after_to_365_days_after
# ...                                                               ...
# 4530  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4531  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4532  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4533  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4534  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4535  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4536  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4537  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4538  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4539  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4540  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4541  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4542  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4543  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4544  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4545  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4546  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4547  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4548  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4549  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4550  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4551  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4552  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4553  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4554  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4555  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4556  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4557  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4558  other_viral_infection_onset_from_0_days_after_to_365_days_after
# 4559  other_viral_infection_onset_from_0_days_after_to_365_days_after
#
#       threshold_numeric  threshold_occurring  window_start_numeric  \
# 0                  0.05                 0.05                  -271
# 1                  0.05                 0.05                  -271
# 2                  0.35                 0.05                  -301
# 3                  0.05                 0.05                  -241
# 4                  0.05                 0.05                  -271
# 5                  0.35                 0.05                  -301
# 6                  0.05                 0.05                  -241
# 7                  0.05                 0.05                  -301
# 8                  0.05                 0.05                  -271
# 9                  0.05                 0.05                  -241
# 10                 0.05                 0.05                  -271
# 11                 0.05                 0.05                  -361
# 12                 0.20                 0.05                  -151
# 13                 0.15                 0.05                  -211
# 14                 0.35                 0.05                  -301
# 15                 0.15                 0.05                  -361
# 16                 0.10                 0.05                  -211
# 17                 0.20                 0.05                  -151
# 18                 0.30                 0.05                  -271
# 19                 0.25                 0.05                  -121
# 20                 0.35                 0.05                  -361
# 21                 0.15                 0.05                  -361
# 22                 0.35                 0.05                  -301
# 23                 0.35                 0.05                  -301
# 24                 0.15                 0.05                  -361
# 25                 0.20                 0.05                  -151
# 26                 0.35                 0.05                  -271
# 27                 0.05                 0.05                  -271
# 28                 0.30                 0.05                  -271
# 29                 0.05                 0.05                  -301
# ...                 ...                  ...                   ...
# 4530               0.40                 0.05                  -331
# 4531               0.40                 0.05                  -301
# 4532               0.35                 0.05                   -91
# 4533               0.85                 0.05                  -301
# 4534               0.85                 0.05                  -271
# 4535               0.10                 0.05                  -361
# 4536               0.90                 0.05                  -241
# 4537               0.55                 0.05                  -241
# 4538               0.85                 0.05                  -151
# 4539               0.30                 0.05                  -211
# 4540               0.25                 0.05                  -211
# 4541               0.80                 0.05                  -301
# 4542               0.65                 0.05                  -361
# 4543               0.10                 0.05                  -361
# 4544               0.10                 0.05                  -211
# 4545               0.95                 0.05                  -241
# 4546               0.60                 0.05                  -361
# 4547               0.60                 0.05                  -151
# 4548               0.55                 0.05                  -301
# 4549               0.40                 0.05                  -361
# 4550               0.15                 0.05                  -241
# 4551               0.50                 0.05                  -181
# 4552               0.70                 0.05                  -241
# 4553               0.50                 0.05                  -331
# 4554               0.65                 0.05                  -301
# 4555               0.10                 0.05                  -211
# 4556               0.15                 0.05                  -331
# 4557               0.30                 0.05                  -211
# 4558               0.65                 0.05                  -151
# 4559               0.40                 0.05                  -241
#
#       window_start_occurring
# 0                       -361
# 1                       -361
# 2                       -361
# 3                       -361
# 4                       -361
# 5                       -361
# 6                       -361
# 7                       -361
# 8                       -361
# 9                       -361
# 10                      -361
# 11                      -361
# 12                      -361
# 13                      -361
# 14                      -361
# 15                      -361
# 16                      -361
# 17                      -361
# 18                      -361
# 19                      -361
# 20                      -361
# 21                      -361
# 22                      -361
# 23                      -361
# 24                      -361
# 25                      -361
# 26                      -361
# 27                      -361
# 28                      -361
# 29                      -361
# ...                      ...
# 4530                    -361
# 4531                    -361
# 4532                    -361
# 4533                    -361
# 4534                    -361
# 4535                    -361
# 4536                    -361
# 4537                    -361
# 4538                    -361
# 4539                    -361
# 4540                    -361
# 4541                    -361
# 4542                    -361
# 4543                    -361
# 4544                    -361
# 4545                    -361
# 4546                    -361
# 4547                    -361
# 4548                    -361
# 4549                    -361
# 4550                    -361
# 4551                    -361
# 4552                    -361
# 4553                    -361
# 4554                    -361
# 4555                    -361
# 4556                    -361
# 4557                    -361
# 4558                    -361
# 4559                    -361
#
# [4560 rows x 11 columns]
